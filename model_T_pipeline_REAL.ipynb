# %%
#imports
import pandas as pd
import numpy as np
import json
from sklearn.model_selection import train_test_split

# %%
#load dataset
def load_dataset(path):
    df = pd.read_csv(path)
    print("Dataset loaded:", df.shape)
    return df

# %%
#load rules (rules.json must be valid JSON)
def load_rules(path):
    with open(path, "r") as f:
        rules = json.load(f)
    print("Rules loaded")
    return rules

# %%
#ensure hidden column exists (in both train and test)
def ensure_hidden_column(df, rules):
    # assumes rules["variables"] exists and lists hidden variables
    hidden_vars = list(rules.get("variables", {}).keys())
    for hv in hidden_vars:
        if hv not in df.columns:
            df[hv] = np.nan
    return df

# %%
#apply rules to a dataframe (do NOT apply rules to test set)
def apply_rules(df, rules):
    for rule in rules.get("rules", []):
        condition = rule["condition"]
        mask = df.eval(condition)
        if "assign" in rule:
            for var, val in rule["assign"].items():
                df.loc[mask & df[var].isna(), var] = val
        elif "formula" in rule:
            hv = list(rules.get("variables", {}).keys())[0]
            values = df.eval(rule["formula"])
            df.loc[mask & df[hv].isna(), hv] = values
    return df

# %%
# =========================
# CONFIG (GLOBAL SETTINGS)
# =========================

CONFIG = {
    # Paths
    "dataset_path": r"D:\project MODEL.T\dataset\new files\MASTERDATA.csv",
    "rules_path": r"D:\project MODEL.T\rule.json\json_RULE.json",
    "output_path": r"D:\project MODEL.T\dataset\model_T_results6.csv",

    # Split
    "test_size": 0.2,

    # Reproducibility
    "random_seed": 42,

    # Training params  
    "learning_rate": 0.001,
    "epochs": 300,
    "batch_size": 32,

    # Model / similarity params (keep for future use)
    "k_neighbors": 10,
    "buffer_pct": 0.10,
    "similarity_sigma": 1.0,
}

# %%
# load data and split
df = load_dataset(CONFIG["dataset_path"])
rules = load_rules(CONFIG["rules_path"])

# create hidden column placeholders in full df so test set has column too
df = ensure_hidden_column(df, rules)

# train/test split - test set must be held-out
train_df, test_df = train_test_split(
    df,
    test_size=CONFIG["test_size"],
    random_state=CONFIG["random_seed"]
)

print("Train:", len(train_df), "Test:", len(test_df))
# Out:
# Dataset loaded: (10000, 6)
# Rules loaded
# Train: 8000 Test: 2000

# %%
#quality check

import numpy as np
from numpy.linalg import matrix_rank, cond as matrix_cond

TARGET_COL = "target"

# ── Step 1: apply rules to a temp copy (never touch real train_df) ──
df_temp = train_df.copy()
hv      = list(rules["variables"].keys())[0]
h_range = rules["variables"][hv]["range"]

if hv not in df_temp.columns:
    df_temp[hv] = np.nan

for rule in rules["rules"]:
    mask = df_temp.eval(rule["condition"])

    
    if "assign" in rule:
        for var, val in rule["assign"].items():
            if var not in df_temp.columns:
                df_temp[var] = np.nan
            df_temp.loc[mask & df_temp[var].isna(), var] = val

    
    elif "formula" in rule:
        values = df_temp.eval(rule["formula"])

        # apply to hidden variable (hv)
        df_temp.loc[mask & df_temp[hv].isna(), hv] = values

    else:
        print(f"⚠️ Rule '{rule.get('name','unknown')}' has neither 'assign' nor 'formula'")

labeled   = df_temp[df_temp[hv].notna()].copy()
unlabeled = df_temp[df_temp[hv].isna()].copy()

# ── Step 2: build feature matrix from labeled rows ──
features_chk = [c for c in df_temp.select_dtypes(include=[np.number]).columns
                if c != TARGET_COL]

N     = len(df_temp)
n_lab = len(labeled)
n_unl = len(unlabeled)
pct   = n_lab / N * 100

X_lab = labeled[features_chk].values.astype(float)

# ── Step 3: compute rank ──
rank   = matrix_rank(X_lab)
nfeats = len(features_chk)

# ── Step 4: compute condition number (on normalized matrix) ──
fmean = X_lab.mean(axis=0)
fstd  = X_lab.std(axis=0)
fstd[fstd == 0] = 1e-9
X_norm_chk = (X_lab - fmean) / fstd
try:
    cond_num = matrix_cond(X_norm_chk)
except Exception:
    cond_num = float("inf")

# ── Step 5: per-feature std in labeled set ──
feat_stds  = {f: X_lab[:, i].std() for i, f in enumerate(features_chk)}
zero_feats = [f for f, s in feat_stds.items() if s < 0.01]

# ── Step 6: hidden variable value distribution ──
hv_dist   = labeled[hv].value_counts().sort_index().to_dict()
hv_unique = len(hv_dist)

# ── Step 7: evaluate each check ──
chk_coverage = pct >= 15
chk_rank     = rank == nfeats
chk_cond     = cond_num < 100
chk_zero     = len(zero_feats) == 0
chk_hv       = hv_unique >= 2
all_pass     = chk_coverage and chk_rank and chk_cond and chk_zero and chk_hv

def tick(b): return "PASS" if b else "FAIL"
def cq(v):   return "excellent" if v<10 else "good" if v<30 else "poor" if v<100 else "CRITICAL"

# ── Print report ──

print("  RULE QUALITY CHECK")


print(f"\n  Rows total      : {N}")
print(f"  Labeled rows    : {n_lab}  ({pct:.1f}%)")
print(f"  Unlabeled rows  : {n_unl}")
print(f"  Features        : {features_chk}")


# Check 1 — coverage
print(f"  CHECK 1  Coverage >= 15%")
print(f"  Result : {tick(chk_coverage)}  ({pct:.1f}% labeled)")
if not chk_coverage:
    print(f"  Fix    : add more rules to label at least 15% of rows")
print()

# Check 2 — rank  (most important)
print(f"  CHECK 2  Matrix rank == number of features")
print(f"  Result : {tick(chk_rank)}  rank = {rank}  /  n_features = {nfeats}")
if not chk_rank:
    print(f"  Fix    : your rules fix a linear constraint across features")
    print(f"           (e.g. m1+m2+m3+m4 always = 3 in labeled rows)")
    print(f"           add rules with different sums or laser thresholds")
    print(f"           so labeled rows have real variance in all features")
print()

# Check 3 — condition number
cond_str = f"{cond_num:.1f}" if cond_num < 1e10 else f"{cond_num:.2e}"
print(f"  CHECK 3  Condition number < 100")
print(f"  Result : {tick(chk_cond)}  {cond_str}  [{cq(cond_num)}]")
if not chk_cond:
    print(f"  Fix    : same as Check 2 — add diverse rules")
print()

# Check 4 — per-feature variance
print(f"  CHECK 4  Every feature has variance > 0 in labeled rows")
print(f"  Result : {tick(chk_zero)}")
for f, s in feat_stds.items():
    bar  = chr(9608) * min(int(s * 15), 30)
    flag = "  <- near zero" if s < 0.01 else ""
    print(f"           {f:<10}  std = {s:.4f}   {bar}{flag}")
if not chk_zero:
    print(f"  Fix    : features {zero_feats} never change in labeled rows")
    print(f"           add rules where those features take different values")
print()

# Check 5 — hidden variable variety
print(f"  CHECK 5  Hidden variable has >= 2 distinct values in labeled rows")
print(f"  Result : {tick(chk_hv)}  ({hv_unique} distinct values)")
for val, cnt in hv_dist.items():
    print(f"           {hv} = {val}  ->  {cnt} rows")
if not chk_hv:
    print(f"  Fix    : all labeled rows assign the same {hv} value")
    print(f"           add at least one rule that assigns a different value")


if all_pass:
    print(f"  ALL CHECKS PASSED")
    print(f"  rules are usable — proceed with training")
else:
    print(f"  ONE OR MORE CHECKS FAILED")
    print(f"  fix the rules in your JSON file and re-run Cell A then this cell")
# Out:
#   RULE QUALITY CHECK
#
#   Rows total      : 8000
#   Labeled rows    : 2394  (29.9%)
#   Unlabeled rows  : 5606
#   Features        : ['m1', 'm2', 'm3', 'm4', 'laser', 'm5']
#   CHECK 1  Coverage >= 15%
#   Result : PASS  (29.9% labeled)
#
#   CHECK 2  Matrix rank == number of features
#   Result : PASS  rank = 6  /  n_features = 6
#
#   CHECK 3  Condition number < 100
#   Result : PASS  1.9  [excellent]
#
#   CHECK 4  Every feature has variance > 0 in labeled rows
#   Result : PASS
#            m1          std = 0.4993   ███████
#            m2          std = 0.4803   ███████
#            m3          std = 0.4704   ███████
#            m4          std = 0.4999   ███████
#            laser       std = 5.2556   ██████████████████████████████
#            m5          std = 0.8609   ████████████
#
#   CHECK 5  Hidden variable has >= 2 distinct values in labeled rows
#   Result : PASS  (2394 distinct values)
#            m5 = 0.00015884174999980516  ->  1 rows
#            m5 = 0.001653477  ->  1 rows
#            m5 = 0.00187708125  ->  1 rows
#            m5 = 0.0022897199999998286  ->  1 rows
#            m5 = 0.0036793575  ->  1 rows
#            m5 = 0.00460612575  ->  1 rows
#            m5 = 0.00516552  ->  1 rows
#            m5 = 0.005320282499999607  ->  1 rows
#            m5 = 0.00897573750000058  ->  1 rows
#            m5 = 0.009750232499999845  ->  1 rows
#            m5 = 0.010235347499999214  ->  1 rows
#            m5 = 0.010371952499999004  ->  1 rows
#            m5 = 0.011028826500000477  ->  1 rows
#            m5 = 0.012635692499999518  ->  1 rows
#            m5 = 0.012947692500000496  ->  1 rows
#            m5 = 0.01470623160000013  ->  1 rows
#            m5 = 0.01477658159999997  ->  1 rows
#            m5 = 0.018437714999999688  ->  1 rows
#            m5 = 0.01971676425000002  ->  1 rows
#            m5 = 0.021456090000000927  ->  1 rows
#            m5 = 0.02328254879999996  ->  1 rows
#            m5 = 0.023304742500000142  ->  1 rows
#            m5 = 0.027291106499999884  ->  1 rows
#            m5 = 0.027685688999999767  ->  1 rows
#            m5 = 0.030490965000001147  ->  1 rows
#            m5 = 0.03391316549999979  ->  1 rows
#            m5 = 0.03466981725000018  ->  1 rows
#            m5 = 0.03497513399999974  ->  1 rows
#            m5 = 0.037826425500000004  ->  1 rows
#            m5 = 0.0386796900000002  ->  1 rows
#            m5 = 0.03948600750000031  ->  1 rows
#            m5 = 0.04246395000000014  ->  1 rows
#            m5 = 0.04404101250000059  ->  1 rows
#            m5 = 0.04750971225  ->  1 rows
#            m5 = 0.048619822500000076  ->  1 rows
#            m5 = 0.049216935  ->  1 rows
#            m5 = 0.05035457624999973  ->  1 rows
#            m5 = 0.05179575824999971  ->  1 rows
#            m5 = 0.05361128250000036  ->  1 rows
#            m5 = 0.05744544674999963  ->  1 rows
#            m5 = 0.057878437499999436  ->  1 rows
#            m5 = 0.0581456549999988  ->  1 rows
#            m5 = 0.06103717320000026  ->  1 rows
#            m5 = 0.06564301049999965  ->  1 rows
#            m5 = 0.06661374750000038  ->  1 rows
#            m5 = 0.06747888749999964  ->  1 rows
#            m5 = 0.06801938999999946  ->  1 rows
#            m5 = 0.06914903925  ->  1 rows
#            m5 = 0.07193108775000034  ->  1 rows
#            m5 = 0.07238045250000003  ->  1 rows
#            m5 = 0.07436493375000008  ->  1 rows
#            m5 = 0.0802880862000002  ->  1 rows
#            m5 = 0.08100201000000018  ->  1 rows
#            m5 = 0.08270245800000042  ->  1 rows
#            m5 = 0.0829029375000001  ->  1 rows
#            m5 = 0.08384491875000033  ->  1 rows
#            m5 = 0.08559330975000057  ->  1 rows
#            m5 = 0.08751081120000012  ->  1 rows
#            m5 = 0.08885866199999981  ->  1 rows
#            m5 = 0.08898225450000008  ->  1 rows
#            m5 = 0.08917332750000018  ->  1 rows
#            m5 = 0.0895839905999999  ->  1 rows
#            m5 = 0.0904105785  ->  1 rows
#            m5 = 0.09042540300000024  ->  1 rows
#            m5 = 0.09208377300000015  ->  1 rows
#            m5 = 0.09381399674999935  ->  1 rows
#            m5 = 0.09428318775  ->  1 rows
#            m5 = 0.09493462499999872  ->  1 rows
#            m5 = 0.09674164425000001  ->  1 rows
#            m5 = 0.09842255100000052  ->  1 rows
#            m5 = 0.09898742474999978  ->  1 rows
#            m5 = 0.1002231899999999  ->  1 rows
#            m5 = 0.10148789175000017  ->  1 rows
#            m5 = 0.10380230249999922  ->  1 rows
#            m5 = 0.1045872263999998  ->  1 rows
#            m5 = 0.10548357749999981  ->  1 rows
#            m5 = 0.10757799480000009  ->  1 rows
#            m5 = 0.1090947225  ->  1 rows
#            m5 = 0.1093596539999997  ->  1 rows
#            m5 = 0.11015628224999974  ->  1 rows
#            m5 = 0.11290293000000018  ->  1 rows
#            m5 = 0.11300687250000063  ->  1 rows
#            m5 = 0.11370779459999997  ->  1 rows
#            m5 = 0.11412304800000062  ->  1 rows
#            m5 = 0.11469192000000028  ->  1 rows
#            m5 = 0.11573282550000008  ->  1 rows
#            m5 = 0.11855551739999974  ->  1 rows
#            m5 = 0.11856186749999997  ->  1 rows
#            m5 = 0.1202804777999999  ->  1 rows
#            m5 = 0.12093428249999949  ->  1 rows
#            m5 = 0.12102304575000034  ->  1 rows
#            m5 = 0.121096422  ->  1 rows
#            m5 = 0.12134379750000068  ->  1 rows
#            m5 = 0.12158496750000047  ->  1 rows
#            m5 = 0.12262718760000019  ->  1 rows
#            m5 = 0.122760384  ->  1 rows
#            m5 = 0.12505882259999979  ->  1 rows
#            m5 = 0.1260294174000002  ->  1 rows
#            m5 = 0.126966324  ->  1 rows
#            m5 = 0.12731629800000022  ->  1 rows
#            m5 = 0.12759072224999968  ->  1 rows
#            m5 = 0.1280972475000013  ->  1 rows
#            m5 = 0.12829857780000023  ->  1 rows
#            m5 = 0.1303519350000002  ->  1 rows
#            m5 = 0.1320165899999992  ->  1 rows
#            m5 = 0.13240572675  ->  1 rows
#            m5 = 0.13336551375000028  ->  1 rows
#            m5 = 0.13540681349999995  ->  1 rows
#            m5 = 0.13599254249999948  ->  1 rows
#            m5 = 0.13741819499999952  ->  1 rows
#            m5 = 0.1377688920000002  ->  1 rows
#            m5 = 0.13857533249999943  ->  1 rows
#            m5 = 0.138808803  ->  1 rows
#            m5 = 0.13893424049999936  ->  1 rows
#            m5 = 0.13900244174999998  ->  1 rows
#            m5 = 0.14111875499999949  ->  1 rows
#            m5 = 0.1412265525000005  ->  1 rows
#            m5 = 0.14200204500000035  ->  1 rows
#            m5 = 0.14252394749999997  ->  1 rows
#            m5 = 0.14515613699999985  ->  1 rows
#            m5 = 0.14542752525  ->  1 rows
#            m5 = 0.14681833049999998  ->  1 rows
#            m5 = 0.14739053924999967  ->  1 rows
#            m5 = 0.14891900025000027  ->  1 rows
#            m5 = 0.15806141249999994  ->  1 rows
#            m5 = 0.15899132550000017  ->  1 rows
#            m5 = 0.15924807750000025  ->  1 rows
#            m5 = 0.16145159850000024  ->  1 rows
#            m5 = 0.1623331050000001  ->  1 rows
#            m5 = 0.16343209575  ->  1 rows
#            m5 = 0.16396335659999986  ->  1 rows
#            m5 = 0.1653660097500005  ->  1 rows
#            m5 = 0.1658159805  ->  1 rows
#            m5 = 0.16823714249999977  ->  1 rows
#            m5 = 0.16875783525  ->  1 rows
#            m5 = 0.169041693  ->  1 rows
#            m5 = 0.17142265440000024  ->  1 rows
#            m5 = 0.1735980975  ->  1 rows
#            m5 = 0.17799809625000007  ->  1 rows
#            m5 = 0.17968034175  ->  1 rows
#            m5 = 0.18172905150000002  ->  1 rows
#            m5 = 0.1819586377500002  ->  1 rows
#            m5 = 0.18408783674999984  ->  1 rows
#            m5 = 0.1856934615000001  ->  1 rows
#            m5 = 0.18766399679999973  ->  1 rows
#            m5 = 0.18834367860000026  ->  1 rows
#            m5 = 0.19399347749999984  ->  1 rows
#            m5 = 0.1957012012499999  ->  1 rows
#            m5 = 0.1968420015000003  ->  1 rows
#            m5 = 0.20013396225000024  ->  1 rows
#            m5 = 0.20054229750000108  ->  1 rows
#            m5 = 0.200643591  ->  1 rows
#            m5 = 0.20121652799999978  ->  1 rows
#            m5 = 0.20267052149999998  ->  1 rows
#            m5 = 0.20323218750000027  ->  1 rows
#            m5 = 0.2034240905999999  ->  1 rows
#            m5 = 0.2050773264  ->  1 rows
#            m5 = 0.20607840750000062  ->  1 rows
#            m5 = 0.20611373249999976  ->  1 rows
#            m5 = 0.20698438500000016  ->  1 rows
#            m5 = 0.2077145325  ->  1 rows
#            m5 = 0.2107634771999999  ->  1 rows
#            m5 = 0.21284662500000007  ->  1 rows
#            m5 = 0.2137177342500003  ->  1 rows
#            m5 = 0.21515977124999974  ->  1 rows
#            m5 = 0.21539176950000005  ->  1 rows
#            m5 = 0.215510388  ->  1 rows
#            m5 = 0.2174081160000001  ->  1 rows
#            m5 = 0.21769319249999963  ->  1 rows
#            m5 = 0.21805441499999922  ->  1 rows
#            m5 = 0.2180776927500001  ->  1 rows
#            m5 = 0.2182432972499999  ->  1 rows
#            m5 = 0.21879809249999926  ->  1 rows
#            m5 = 0.2192827961999999  ->  1 rows
#            m5 = 0.2196707099999997  ->  1 rows
#            m5 = 0.21969948749999935  ->  1 rows
#            m5 = 0.21971323125000009  ->  1 rows
#            m5 = 0.2202582869999996  ->  1 rows
#            m5 = 0.22185058125  ->  1 rows
#            m5 = 0.22684934249999955  ->  1 rows
#            m5 = 0.22735449149999987  ->  1 rows
#            m5 = 0.22898052000000035  ->  1 rows
#            m5 = 0.22947445949999978  ->  1 rows
#            m5 = 0.23249590500000128  ->  1 rows
#            m5 = 0.23332900349999997  ->  1 rows
#            m5 = 0.23377051125000037  ->  1 rows
#            m5 = 0.23462349975000008  ->  1 rows
#            m5 = 0.23494739700000022  ->  1 rows
#            m5 = 0.23751075374999964  ->  1 rows
#            m5 = 0.24379067249999942  ->  1 rows
#            m5 = 0.24569406749999967  ->  1 rows
#            m5 = 0.24686578500000023  ->  1 rows
#            m5 = 0.24784094699999998  ->  1 rows
#            m5 = 0.24836617080000012  ->  1 rows
#            m5 = 0.2491252725000006  ->  1 rows
#            m5 = 0.2500324524  ->  1 rows
#            m5 = 0.2525488650000005  ->  1 rows
#            m5 = 0.2535089175000005  ->  1 rows
#            m5 = 0.25408707000000064  ->  1 rows
#            m5 = 0.25826670660000006  ->  1 rows
#            m5 = 0.2594139225000003  ->  1 rows
#            m5 = 0.2616567974999997  ->  1 rows
#            m5 = 0.26324145  ->  1 rows
#            m5 = 0.26348537880000006  ->  1 rows
#            m5 = 0.26539741725  ->  1 rows
#            m5 = 0.26702178120000003  ->  1 rows
#            m5 = 0.26705231279999975  ->  1 rows
#            m5 = 0.2673688102499998  ->  1 rows
#            m5 = 0.2683959630000001  ->  1 rows
#            m5 = 0.2693328150000003  ->  1 rows
#            m5 = 0.26982036300000045  ->  1 rows
#            m5 = 0.2705927406000002  ->  1 rows
#            m5 = 0.278880879  ->  1 rows
#            m5 = 0.2792247892500006  ->  1 rows
#            m5 = 0.2825201639999999  ->  1 rows
#            m5 = 0.28285888259999986  ->  1 rows
#            m5 = 0.28429342874999985  ->  1 rows
#            m5 = 0.2854712564999997  ->  1 rows
#            m5 = 0.2865312675  ->  1 rows
#            m5 = 0.2867204324999997  ->  1 rows
#            m5 = 0.2892756074999996  ->  1 rows
#            m5 = 0.29012927579999986  ->  1 rows
#            m5 = 0.29149008600000004  ->  1 rows
#            m5 = 0.29296529700000007  ->  1 rows
#            m5 = 0.29405352075  ->  1 rows
#            m5 = 0.29552670375  ->  1 rows
#            m5 = 0.29793394500000003  ->  1 rows
#            m5 = 0.2983407524999997  ->  1 rows
#            m5 = 0.29840278080000004  ->  1 rows
#            m5 = 0.2985086484000002  ->  1 rows
#            m5 = 0.2989825065  ->  1 rows
#            m5 = 0.2995093247999998  ->  1 rows
#            m5 = 0.2997824272499998  ->  1 rows
#            m5 = 0.30052059975  ->  1 rows
#            m5 = 0.3015454709999994  ->  1 rows
#            m5 = 0.30174782925  ->  1 rows
#            m5 = 0.30419340750000057  ->  1 rows
#            m5 = 0.30508296  ->  1 rows
#            m5 = 0.30642838499999936  ->  1 rows
#            m5 = 0.3069895697999998  ->  1 rows
#            m5 = 0.3083959649999999  ->  1 rows
#            m5 = 0.31078580280000023  ->  1 rows
#            m5 = 0.3120612825000002  ->  1 rows
#            m5 = 0.31292208974999997  ->  1 rows
#            m5 = 0.3133455674999994  ->  1 rows
#            m5 = 0.31347783750000024  ->  1 rows
#            m5 = 0.31420736250000036  ->  1 rows
#            m5 = 0.3146180219999998  ->  1 rows
#            m5 = 0.31472776260000007  ->  1 rows
#            m5 = 0.3150433844999998  ->  1 rows
#            m5 = 0.3165698532000002  ->  1 rows
#            m5 = 0.31681987619999974  ->  1 rows
#            m5 = 0.31788474840000003  ->  1 rows
#            m5 = 0.31945551000000005  ->  1 rows
#            m5 = 0.32041610775  ->  1 rows
#            m5 = 0.3224227852499999  ->  1 rows
#            m5 = 0.32262775500000007  ->  1 rows
#            m5 = 0.3236435602499994  ->  1 rows
#            m5 = 0.3237631194000002  ->  1 rows
#            m5 = 0.3238773816  ->  1 rows
#            m5 = 0.32520017475  ->  1 rows
#            m5 = 0.3257140992  ->  1 rows
#            m5 = 0.3339345375000011  ->  1 rows
#            m5 = 0.3385966695000002  ->  1 rows
#            m5 = 0.3391936852499997  ->  1 rows
#            m5 = 0.3406053382500005  ->  1 rows
#            m5 = 0.34098613499999963  ->  1 rows
#            m5 = 0.34133388060000003  ->  1 rows
#            m5 = 0.3413717032499999  ->  1 rows
#            m5 = 0.34200207749999967  ->  1 rows
#            m5 = 0.3421149105  ->  1 rows
#            m5 = 0.34283285249999995  ->  1 rows
#            m5 = 0.3435994777500002  ->  1 rows
#            m5 = 0.34473652019999984  ->  1 rows
#            m5 = 0.34539295019999977  ->  1 rows
#            m5 = 0.3465822195000001  ->  1 rows
#            m5 = 0.34672260000000055  ->  1 rows
#            m5 = 0.34719376575  ->  1 rows
#            m5 = 0.34719518025  ->  1 rows
#            m5 = 0.34725473175000054  ->  1 rows
#            m5 = 0.34736592600000016  ->  1 rows
#            m5 = 0.34791210675  ->  1 rows
#            m5 = 0.34840070175  ->  1 rows
#            m5 = 0.35040499125  ->  1 rows
#            m5 = 0.350663631  ->  1 rows
#            m5 = 0.35106936975000025  ->  1 rows
#            m5 = 0.3551339714999999  ->  1 rows
#            m5 = 0.3556599366000002  ->  1 rows
#            m5 = 0.3564603059999998  ->  1 rows
#            m5 = 0.3565843740000001  ->  1 rows
#            m5 = 0.3565885365000001  ->  1 rows
#            m5 = 0.35812115174999937  ->  1 rows
#            m5 = 0.36156185999999924  ->  1 rows
#            m5 = 0.36231006600000026  ->  1 rows
#            m5 = 0.36243684  ->  1 rows
#            m5 = 0.3626418432000001  ->  1 rows
#            m5 = 0.362687782500001  ->  1 rows
#            m5 = 0.36350233379999997  ->  1 rows
#            m5 = 0.3645394019999999  ->  1 rows
#            m5 = 0.3646036350000008  ->  1 rows
#            m5 = 0.36589146750000046  ->  1 rows
#            m5 = 0.36605410080000006  ->  1 rows
#            m5 = 0.3680845230000001  ->  1 rows
#            m5 = 0.3686380575000001  ->  1 rows
#            m5 = 0.3715326378000002  ->  1 rows
#            m5 = 0.3722541090000002  ->  1 rows
#            m5 = 0.37602888959999986  ->  1 rows
#            m5 = 0.38152939050000034  ->  1 rows
#            m5 = 0.38331426974999994  ->  1 rows
#            m5 = 0.38370370875000015  ->  1 rows
#            m5 = 0.38509818750000013  ->  1 rows
#            m5 = 0.38773269420000017  ->  1 rows
#            m5 = 0.3881801625000012  ->  1 rows
#            m5 = 0.3896307642  ->  1 rows
#            m5 = 0.3910899905999999  ->  1 rows
#            m5 = 0.3918595709999998  ->  1 rows
#            m5 = 0.3920799075000003  ->  1 rows
#            m5 = 0.3923748772500004  ->  1 rows
#            m5 = 0.3944598941999999  ->  1 rows
#            m5 = 0.3961656372000002  ->  1 rows
#            m5 = 0.397490437500001  ->  1 rows
#            m5 = 0.39851076750000036  ->  1 rows
#            m5 = 0.39947530350000005  ->  1 rows
#            m5 = 0.4003533997499997  ->  1 rows
#            m5 = 0.4005735119999998  ->  1 rows
#            m5 = 0.4006886399999998  ->  1 rows
#            m5 = 0.40095129750000025  ->  1 rows
#            m5 = 0.4016198568  ->  1 rows
#            m5 = 0.4020544500000005  ->  1 rows
#            m5 = 0.40461929774999994  ->  1 rows
#            m5 = 0.40762184474999996  ->  1 rows
#            m5 = 0.40807199999999977  ->  1 rows
#            m5 = 0.4085050949999989  ->  1 rows
#            m5 = 0.4086724184999997  ->  1 rows
#            m5 = 0.4087213679999997  ->  1 rows
#            m5 = 0.4112243160000002  ->  1 rows
#            m5 = 0.41143153125  ->  1 rows
#            m5 = 0.41213469974999994  ->  1 rows
#            m5 = 0.4121995649999999  ->  1 rows
#            m5 = 0.41283231825  ->  1 rows
#            m5 = 0.4156517617500004  ->  1 rows
#            m5 = 0.4162282296000002  ->  1 rows
#            m5 = 0.41704775250000026  ->  1 rows
#            m5 = 0.41721366750000044  ->  1 rows
#            m5 = 0.42268557150000063  ->  1 rows
#            m5 = 0.423693093  ->  1 rows
#            m5 = 0.4240619417999998  ->  1 rows
#            m5 = 0.42611244750000044  ->  1 rows
#            m5 = 0.426618189  ->  1 rows
#            m5 = 0.4285971825000008  ->  1 rows
#            m5 = 0.4288058804999997  ->  1 rows
#            m5 = 0.42888910649999934  ->  1 rows
#            m5 = 0.42979826774999985  ->  1 rows
#            m5 = 0.43126111950000023  ->  1 rows
#            m5 = 0.4334508935999999  ->  1 rows
#            m5 = 0.4358639775000004  ->  1 rows
#            m5 = 0.43672001625  ->  1 rows
#            m5 = 0.43728756825000037  ->  1 rows
#            m5 = 0.4381354307999999  ->  1 rows
#            m5 = 0.4402555275000002  ->  1 rows
#            m5 = 0.44376275475000004  ->  1 rows
#            m5 = 0.44418834750000014  ->  1 rows
#            m5 = 0.44528567249999984  ->  1 rows
#            m5 = 0.44766265500000024  ->  1 rows
#            m5 = 0.44777967449999956  ->  1 rows
#            m5 = 0.4479047928000002  ->  1 rows
#            m5 = 0.4498243578000002  ->  1 rows
#            m5 = 0.4506708075000003  ->  1 rows
#            m5 = 0.45071478119999975  ->  1 rows
#            m5 = 0.4521197655  ->  1 rows
#            m5 = 0.45516233475000023  ->  1 rows
#            m5 = 0.45551495099999983  ->  1 rows
#            m5 = 0.45624042750000005  ->  1 rows
#            m5 = 0.45749084474999996  ->  1 rows
#            m5 = 0.4580818822499999  ->  1 rows
#            m5 = 0.4585032337499999  ->  1 rows
#            m5 = 0.4586258272500001  ->  1 rows
#            m5 = 0.45975886050000003  ->  1 rows
#            m5 = 0.4614807824999998  ->  1 rows
#            m5 = 0.46169299499999905  ->  1 rows
#            m5 = 0.4621759702499999  ->  1 rows
#            m5 = 0.4622953222499997  ->  1 rows
#            m5 = 0.46397164874999985  ->  1 rows
#            m5 = 0.4640019318  ->  1 rows
#            m5 = 0.4653926377499997  ->  1 rows
#            m5 = 0.4671493425000004  ->  1 rows
#            m5 = 0.46722651975  ->  1 rows
#            m5 = 0.46781933999999925  ->  1 rows
#            m5 = 0.46979701350000025  ->  1 rows
#            m5 = 0.47162669999999896  ->  1 rows
#            m5 = 0.47635224720000013  ->  1 rows
#            m5 = 0.47887682025000045  ->  1 rows
#            m5 = 0.47966472750000033  ->  1 rows
#            m5 = 0.4813247625000008  ->  1 rows
#            m5 = 0.48208428525000024  ->  1 rows
#            m5 = 0.4834004400000005  ->  1 rows
#            m5 = 0.4843153199999999  ->  1 rows
#            m5 = 0.48738554999999906  ->  1 rows
#            m5 = 0.48794545619999974  ->  1 rows
#            m5 = 0.4884045074999994  ->  1 rows
#            m5 = 0.4884186127499994  ->  1 rows
#            m5 = 0.49057813424999996  ->  1 rows
#            m5 = 0.49294088699999994  ->  1 rows
#            m5 = 0.4929901875000011  ->  1 rows
#            m5 = 0.4930471799999999  ->  1 rows
#            m5 = 0.49328267024999994  ->  1 rows
#            m5 = 0.49366281  ->  1 rows
#            m5 = 0.4951168875000005  ->  1 rows
#            m5 = 0.49564385250000065  ->  1 rows
#            m5 = 0.4978620675000007  ->  1 rows
#            m5 = 0.4982012700000009  ->  1 rows
#            m5 = 0.49827952799999986  ->  1 rows
#            m5 = 0.49946267219999996  ->  1 rows
#            m5 = 0.5003686799999993  ->  1 rows
#            m5 = 0.5038978365  ->  1 rows
#            m5 = 0.5054582549999989  ->  1 rows
#            m5 = 0.5061719928000002  ->  1 rows
#            m5 = 0.5066010247499997  ->  1 rows
#            m5 = 0.50766556275  ->  1 rows
#            m5 = 0.5093238037499996  ->  1 rows
#            m5 = 0.5108471106  ->  1 rows
#            m5 = 0.5113505174999995  ->  1 rows
#            m5 = 0.51194856075  ->  1 rows
#            m5 = 0.51235996125  ->  1 rows
#            m5 = 0.5129472832499999  ->  1 rows
#            m5 = 0.5129979023999999  ->  1 rows
#            m5 = 0.5134166549999999  ->  1 rows
#            m5 = 0.5152727977499993  ->  1 rows
#            m5 = 0.5159234084999995  ->  1 rows
#            m5 = 0.5159588925000005  ->  1 rows
#            m5 = 0.5169665351999999  ->  1 rows
#            m5 = 0.5185523977499997  ->  1 rows
#            m5 = 0.5199300396000002  ->  1 rows
#            m5 = 0.5209309200000002  ->  1 rows
#            m5 = 0.5240516542500002  ->  1 rows
#            m5 = 0.5245706377500001  ->  1 rows
#            m5 = 0.5249616198  ->  1 rows
#            m5 = 0.52866673575  ->  1 rows
#            m5 = 0.53225107725  ->  1 rows
#            m5 = 0.5326489199999989  ->  1 rows
#            m5 = 0.5326523175000002  ->  1 rows
#            m5 = 0.5335495679999998  ->  1 rows
#            m5 = 0.5356306455000001  ->  1 rows
#            m5 = 0.5360903624999995  ->  1 rows
#            m5 = 0.5388463102500001  ->  1 rows
#            m5 = 0.5403248774999998  ->  1 rows
#            m5 = 0.5413136148000001  ->  1 rows
#            m5 = 0.5415125279999999  ->  1 rows
#            m5 = 0.5433880124999995  ->  1 rows
#            m5 = 0.5434724294999997  ->  1 rows
#            m5 = 0.5446622324999999  ->  1 rows
#            m5 = 0.5466754199999997  ->  1 rows
#            m5 = 0.5486868594000001  ->  1 rows
#            m5 = 0.5490203670000001  ->  1 rows
#            m5 = 0.5510501670000001  ->  1 rows
#            m5 = 0.5510857325999998  ->  1 rows
#            m5 = 0.551203149  ->  1 rows
#            m5 = 0.5514916574999997  ->  1 rows
#            m5 = 0.5540381910000001  ->  1 rows
#            m5 = 0.5550293982000001  ->  1 rows
#            m5 = 0.5550430274999991  ->  1 rows
#            m5 = 0.5555158530000002  ->  1 rows
#            m5 = 0.5559435165000002  ->  1 rows
#            m5 = 0.5584131521999998  ->  1 rows
#            m5 = 0.5584834477499998  ->  1 rows
#            m5 = 0.5588175105000004  ->  1 rows
#            m5 = 0.55903084125  ->  1 rows
#            m5 = 0.5592847050000005  ->  1 rows
#            m5 = 0.5604459427499999  ->  1 rows
#            m5 = 0.5634798772500003  ->  1 rows
#            m5 = 0.5637783449999993  ->  1 rows
#            m5 = 0.5656446960000001  ->  1 rows
#            m5 = 0.5687732778000002  ->  1 rows
#            m5 = 0.573011925  ->  1 rows
#            m5 = 0.5743738469999998  ->  1 rows
#            m5 = 0.5751851175000002  ->  1 rows
#            m5 = 0.576665789999999  ->  1 rows
#            m5 = 0.5774582700000002  ->  1 rows
#            m5 = 0.57855785925  ->  1 rows
#            m5 = 0.5814962512500002  ->  1 rows
#            m5 = 0.5822635799999993  ->  1 rows
#            m5 = 0.5842148835  ->  1 rows
#            m5 = 0.5844980040000003  ->  1 rows
#            m5 = 0.5845822452  ->  1 rows
#            m5 = 0.5864308949999997  ->  1 rows
#            m5 = 0.5876056064999999  ->  1 rows
#            m5 = 0.58923058275  ->  1 rows
#            m5 = 0.5903460738000001  ->  1 rows
#            m5 = 0.5909095649999996  ->  1 rows
#            m5 = 0.5918413098  ->  1 rows
#            m5 = 0.5928308324999998  ->  1 rows
#            m5 = 0.5932702365  ->  1 rows
#            m5 = 0.5953215300000005  ->  1 rows
#            m5 = 0.5961581925000004  ->  1 rows
#            m5 = 0.5975964825000002  ->  1 rows
#            m5 = 0.5981108857500002  ->  1 rows
#            m5 = 0.5984465399999999  ->  1 rows
#            m5 = 0.5991122549999988  ->  1 rows
#            m5 = 0.5994472425000006  ->  1 rows
#            m5 = 0.6006220147499994  ->  1 rows
#            m5 = 0.6019905689999994  ->  1 rows
#            m5 = 0.60224447025  ->  1 rows
#            m5 = 0.603612876  ->  1 rows
#            m5 = 0.6053972475  ->  1 rows
#            m5 = 0.6056471346  ->  1 rows
#            m5 = 0.6060764774999994  ->  1 rows
#            m5 = 0.6067218809999997  ->  1 rows
#            m5 = 0.6093784012500003  ->  1 rows
#            m5 = 0.6132034972499993  ->  1 rows
#            m5 = 0.6132872550000004  ->  1 rows
#            m5 = 0.6141303674999996  ->  1 rows
#            m5 = 0.6144659400000005  ->  1 rows
#            m5 = 0.6150840142499998  ->  1 rows
#            m5 = 0.6176594842500001  ->  1 rows
#            m5 = 0.6181744229999998  ->  1 rows
#            m5 = 0.6182448467999998  ->  1 rows
#            m5 = 0.6210906870000003  ->  1 rows
#            m5 = 0.622245543  ->  1 rows
#            m5 = 0.6246674549999995  ->  1 rows
#            m5 = 0.6249455909999998  ->  1 rows
#            m5 = 0.6256722374999995  ->  1 rows
#            m5 = 0.6262811550000005  ->  1 rows
#            m5 = 0.6279116850000004  ->  1 rows
#            m5 = 0.6283125525000002  ->  1 rows
#            m5 = 0.6294803294999998  ->  1 rows
#            m5 = 0.6325687206000001  ->  1 rows
#            m5 = 0.6327479274000002  ->  1 rows
#            m5 = 0.63326465475  ->  1 rows
#            m5 = 0.6347393141999997  ->  1 rows
#            m5 = 0.6358911678  ->  1 rows
#            m5 = 0.6365609795999997  ->  1 rows
#            m5 = 0.6365878380000001  ->  1 rows
#            m5 = 0.6370386495000002  ->  1 rows
#            m5 = 0.6371944709999999  ->  1 rows
#            m5 = 0.6372452856000003  ->  1 rows
#            m5 = 0.6380582370000001  ->  1 rows
#            m5 = 0.63815227425  ->  1 rows
#            m5 = 0.6398774430000002  ->  1 rows
#            m5 = 0.6426645449999999  ->  1 rows
#            m5 = 0.64343864325  ->  1 rows
#            m5 = 0.6439201875  ->  1 rows
#            m5 = 0.6441181800000004  ->  1 rows
#            m5 = 0.6452153250000006  ->  1 rows
#            m5 = 0.6476069325  ->  1 rows
#            m5 = 0.6476433113999999  ->  1 rows
#            m5 = 0.6480429652499999  ->  1 rows
#            m5 = 0.6485432358000001  ->  1 rows
#            m5 = 0.6495371774999996  ->  1 rows
#            m5 = 0.6513159825000003  ->  1 rows
#            m5 = 0.6515604185999999  ->  1 rows
#            m5 = 0.6540054795  ->  1 rows
#            m5 = 0.6560849174999994  ->  1 rows
#            m5 = 0.65744768175  ->  1 rows
#            m5 = 0.6577576151999999  ->  1 rows
#            m5 = 0.6594522210000002  ->  1 rows
#            m5 = 0.6619927612499996  ->  1 rows
#            m5 = 0.6621017804999998  ->  1 rows
#            m5 = 0.6631491479999997  ->  1 rows
#            m5 = 0.664402896  ->  1 rows
#            m5 = 0.6645726074999998  ->  1 rows
#            m5 = 0.6659483872499999  ->  1 rows
#            m5 = 0.6661672349999987  ->  1 rows
#            m5 = 0.6664337616000001  ->  1 rows
#            m5 = 0.6693939540000002  ->  1 rows
#            m5 = 0.6714737040000001  ->  1 rows
#            m5 = 0.6716285100000001  ->  1 rows
#            m5 = 0.67380082875  ->  1 rows
#            m5 = 0.6738427458  ->  1 rows
#            m5 = 0.6747339299999999  ->  1 rows
#            m5 = 0.6766861950000003  ->  1 rows
#            m5 = 0.6767858572500003  ->  1 rows
#            m5 = 0.6781818307499994  ->  1 rows
#            m5 = 0.6827608575000002  ->  1 rows
#            m5 = 0.6832289255999999  ->  1 rows
#            m5 = 0.6837505237499997  ->  1 rows
#            m5 = 0.68463599325  ->  1 rows
#            m5 = 0.6849886650000006  ->  1 rows
#            m5 = 0.6862293457499997  ->  1 rows
#            m5 = 0.6865006416  ->  1 rows
#            m5 = 0.6881601284999999  ->  1 rows
#            m5 = 0.6933529199999997  ->  1 rows
#            m5 = 0.6934248450000009  ->  1 rows
#            m5 = 0.6935184797999998  ->  1 rows
#            m5 = 0.6939506550000001  ->  1 rows
#            m5 = 0.6950103854999994  ->  1 rows
#            m5 = 0.695522532  ->  1 rows
#            m5 = 0.696065379  ->  1 rows
#            m5 = 0.6988326114  ->  1 rows
#            m5 = 0.7001503349999996  ->  1 rows
#            m5 = 0.7005804822000001  ->  1 rows
#            m5 = 0.7039004699999993  ->  1 rows
#            m5 = 0.7055253674999995  ->  1 rows
#            m5 = 0.7057213725000007  ->  1 rows
#            m5 = 0.7060670625000007  ->  1 rows
#            m5 = 0.706698352500001  ->  1 rows
#            m5 = 0.7071401925000003  ->  1 rows
#            m5 = 0.7077175295999998  ->  1 rows
#            m5 = 0.7083217511999997  ->  1 rows
#            m5 = 0.70842959475  ->  1 rows
#            m5 = 0.7086106237500003  ->  1 rows
#            m5 = 0.7091458644  ->  1 rows
#            m5 = 0.7113133125000006  ->  1 rows
#            m5 = 0.7115715074999995  ->  1 rows
#            m5 = 0.7140826575000006  ->  1 rows
#            m5 = 0.7154747154000001  ->  1 rows
#            m5 = 0.7183087349999995  ->  1 rows
#            m5 = 0.7192586175000013  ->  1 rows
#            m5 = 0.7210410457499994  ->  1 rows
#            m5 = 0.7237215786  ->  1 rows
#            m5 = 0.7256570775000011  ->  1 rows
#            m5 = 0.7257387972  ->  1 rows
#            m5 = 0.726348396  ->  1 rows
#            m5 = 0.7295759699999991  ->  1 rows
#            m5 = 0.7299820875000003  ->  1 rows
#            m5 = 0.7300604850000001  ->  1 rows
#            m5 = 0.7302456750000004  ->  1 rows
#            m5 = 0.7334759700000006  ->  1 rows
#            m5 = 0.7338806010000001  ->  1 rows
#            m5 = 0.73665661275  ->  1 rows
#            m5 = 0.73918125075  ->  1 rows
#            m5 = 0.7392874799999998  ->  1 rows
#            m5 = 0.7403106479999999  ->  1 rows
#            m5 = 0.7448733667499998  ->  1 rows
#            m5 = 0.745940328  ->  1 rows
#            m5 = 0.7467254775000001  ->  1 rows
#            m5 = 0.7469500574999994  ->  1 rows
#            m5 = 0.7474269108000001  ->  1 rows
#            m5 = 0.7487674061999998  ->  1 rows
#            m5 = 0.7516589924999995  ->  1 rows
#            m5 = 0.7516954125000006  ->  1 rows
#            m5 = 0.7526125807499999  ->  1 rows
#            m5 = 0.7549266570000002  ->  1 rows
#            m5 = 0.755371574999999  ->  1 rows
#            m5 = 0.7563834300000005  ->  1 rows
#            m5 = 0.7570099155000003  ->  1 rows
#            m5 = 0.757352827500001  ->  1 rows
#            m5 = 0.7592895674999998  ->  1 rows
#            m5 = 0.7619571225000001  ->  1 rows
#            m5 = 0.7625978954999997  ->  1 rows
#            m5 = 0.7643716566000002  ->  1 rows
#            m5 = 0.7646514517499999  ->  1 rows
#            m5 = 0.7661846325000004  ->  1 rows
#            m5 = 0.7680593999999994  ->  1 rows
#            m5 = 0.7697473817999999  ->  1 rows
#            m5 = 0.7703760750000006  ->  1 rows
#            m5 = 0.7712411784000001  ->  1 rows
#            m5 = 0.7714471800000005  ->  1 rows
#            m5 = 0.7720652100000001  ->  1 rows
#            m5 = 0.77272838925  ->  1 rows
#            m5 = 0.7741484441999998  ->  1 rows
#            m5 = 0.7747468854  ->  1 rows
#            m5 = 0.7747824149999998  ->  1 rows
#            m5 = 0.7779626175000001  ->  1 rows
#            m5 = 0.7782374047499996  ->  1 rows
#            m5 = 0.7799271074999994  ->  1 rows
#            m5 = 0.7823921598  ->  1 rows
#            m5 = 0.7825079099999998  ->  1 rows
#            m5 = 0.7825369049999997  ->  1 rows
#            m5 = 0.7837195799999996  ->  1 rows
#            m5 = 0.7840706804999997  ->  1 rows
#            m5 = 0.7855871474999998  ->  1 rows
#            m5 = 0.7871860236000001  ->  1 rows
#            m5 = 0.7874977620000005  ->  1 rows
#            m5 = 0.791618739  ->  1 rows
#            m5 = 0.7930853688  ->  1 rows
#            m5 = 0.7930963950000001  ->  1 rows
#            m5 = 0.7939930582500003  ->  1 rows
#            m5 = 0.7941366108000002  ->  1 rows
#            m5 = 0.7949813016  ->  1 rows
#            m5 = 0.7955185252500003  ->  1 rows
#            m5 = 0.7970077305000003  ->  1 rows
#            m5 = 0.8009740124999998  ->  1 rows
#            m5 = 0.8014194299999999  ->  1 rows
#            m5 = 0.8033644455000006  ->  1 rows
#            m5 = 0.8034875550000002  ->  1 rows
#            m5 = 0.803853854999999  ->  1 rows
#            m5 = 0.8070168314999999  ->  1 rows
#            m5 = 0.808182591  ->  1 rows
#            m5 = 0.80830272675  ->  1 rows
#            m5 = 0.8085635549999997  ->  1 rows
#            m5 = 0.8104951050000007  ->  1 rows
#            m5 = 0.8140466055  ->  1 rows
#            m5 = 0.8144237182500003  ->  1 rows
#            m5 = 0.8175540149999994  ->  1 rows
#            m5 = 0.8187865350000001  ->  1 rows
#            m5 = 0.82009608  ->  1 rows
#            m5 = 0.8202481199999996  ->  1 rows
#            m5 = 0.8221684506000001  ->  1 rows
#            m5 = 0.8222229192  ->  1 rows
#            m5 = 0.8232967357499996  ->  1 rows
#            m5 = 0.823663357500001  ->  1 rows
#            m5 = 0.824460921  ->  1 rows
#            m5 = 0.824790225000001  ->  1 rows
#            m5 = 0.8279370900000007  ->  1 rows
#            m5 = 0.8301515422499999  ->  1 rows
#            m5 = 0.8305284149999994  ->  1 rows
#            m5 = 0.8314928024999997  ->  1 rows
#            m5 = 0.8324599974000001  ->  1 rows
#            m5 = 0.8356034355  ->  1 rows
#            m5 = 0.8370533988000002  ->  1 rows
#            m5 = 0.8370854633999999  ->  1 rows
#            m5 = 0.8376149514000001  ->  1 rows
#            m5 = 0.8378434416000001  ->  1 rows
#            m5 = 0.838025574  ->  1 rows
#            m5 = 0.8399343082499997  ->  1 rows
#            m5 = 0.8400474899999999  ->  1 rows
#            m5 = 0.8409931387500005  ->  1 rows
#            m5 = 0.8413401974999992  ->  1 rows
#            m5 = 0.8424924682499999  ->  1 rows
#            m5 = 0.844494627  ->  1 rows
#            m5 = 0.8464304197500003  ->  1 rows
#            m5 = 0.8476641134999999  ->  1 rows
#            m5 = 0.8504070524999996  ->  1 rows
#            m5 = 0.85126773225  ->  1 rows
#            m5 = 0.8517776831999997  ->  1 rows
#            m5 = 0.8565448897499994  ->  1 rows
#            m5 = 0.8583588300000002  ->  1 rows
#            m5 = 0.8584560862500004  ->  1 rows
#            m5 = 0.8591495399999989  ->  1 rows
#            m5 = 0.8616299264999998  ->  1 rows
#            m5 = 0.86294998125  ->  1 rows
#            m5 = 0.8635068532499997  ->  1 rows
#            m5 = 0.8638774312499999  ->  1 rows
#            m5 = 0.8639869619999998  ->  1 rows
#            m5 = 0.8643507255  ->  1 rows
#            m5 = 0.86492879775  ->  1 rows
#            m5 = 0.8655070425  ->  1 rows
#            m5 = 0.8656600349999999  ->  1 rows
#            m5 = 0.8660658569999999  ->  1 rows
#            m5 = 0.866333088  ->  1 rows
#            m5 = 0.8665153830000003  ->  1 rows
#            m5 = 0.8671357267500002  ->  1 rows
#            m5 = 0.8678397900000006  ->  1 rows
#            m5 = 0.8703534540000001  ->  1 rows
#            m5 = 0.8712069202499997  ->  1 rows
#            m5 = 0.8713447374000001  ->  1 rows
#            m5 = 0.8730443917499997  ->  1 rows
#            m5 = 0.8730658927500001  ->  1 rows
#            m5 = 0.87365179125  ->  1 rows
#            m5 = 0.8739822359999994  ->  1 rows
#            m5 = 0.8745131774999995  ->  1 rows
#            m5 = 0.8762074769999999  ->  1 rows
#            m5 = 0.8777393333999999  ->  1 rows
#            m5 = 0.8778710782500003  ->  1 rows
#            m5 = 0.8781213292500001  ->  1 rows
#            m5 = 0.8795052095999999  ->  1 rows
#            m5 = 0.8820680085  ->  1 rows
#            m5 = 0.8821408184999999  ->  1 rows
#            m5 = 0.8833556130000001  ->  1 rows
#            m5 = 0.8834189106  ->  1 rows
#            m5 = 0.8836461030000002  ->  1 rows
#            m5 = 0.8842627050000003  ->  1 rows
#            m5 = 0.8893720950000006  ->  1 rows
#            m5 = 0.8898069299999998  ->  1 rows
#            m5 = 0.8903621774999992  ->  1 rows
#            m5 = 0.8924587649999998  ->  1 rows
#            m5 = 0.8929840957500006  ->  1 rows
#            m5 = 0.8938858649999997  ->  1 rows
#            m5 = 0.8941921440000002  ->  1 rows
#            m5 = 0.8960265347999998  ->  1 rows
#            m5 = 0.8963142791999997  ->  1 rows
#            m5 = 0.8977078462499999  ->  1 rows
#            m5 = 0.8986338292499996  ->  1 rows
#            m5 = 0.8989564965000001  ->  1 rows
#            m5 = 0.900544695  ->  1 rows
#            m5 = 0.9030845549999995  ->  1 rows
#            m5 = 0.9055085174999995  ->  1 rows
#            m5 = 0.9059454525000006  ->  1 rows
#            m5 = 0.9060259842  ->  1 rows
#            m5 = 0.9062157798000001  ->  1 rows
#            m5 = 0.9098145492000002  ->  1 rows
#            m5 = 0.9101569027500003  ->  1 rows
#            m5 = 0.9114185273999998  ->  1 rows
#            m5 = 0.912887277  ->  1 rows
#            m5 = 0.9135879240000001  ->  1 rows
#            m5 = 0.9138969855000003  ->  1 rows
#            m5 = 0.91550577825  ->  1 rows
#            m5 = 0.9162565125  ->  1 rows
#            m5 = 0.916547778  ->  1 rows
#            m5 = 0.9180370822500001  ->  1 rows
#            m5 = 0.9202036980000001  ->  1 rows
#            m5 = 0.920593947  ->  1 rows
#            m5 = 0.9217187407499999  ->  1 rows
#            m5 = 0.9220808324999998  ->  1 rows
#            m5 = 0.9237749857500002  ->  1 rows
#            m5 = 0.9241724475000006  ->  1 rows
#            m5 = 0.9252653400000006  ->  1 rows
#            m5 = 0.9270430514999999  ->  1 rows
#            m5 = 0.927228507  ->  1 rows
#            m5 = 0.9273234839999998  ->  1 rows
#            m5 = 0.9281464967999997  ->  1 rows
#            m5 = 0.9292207215000001  ->  1 rows
#            m5 = 0.93031305675  ->  1 rows
#            m5 = 0.9304631175000013  ->  1 rows
#            m5 = 0.9311772607500001  ->  1 rows
#            m5 = 0.9313301550000004  ->  1 rows
#            m5 = 0.931452363  ->  1 rows
#            m5 = 0.9321572874  ->  1 rows
#            m5 = 0.9347328675000006  ->  1 rows
#            m5 = 0.9364497757499999  ->  1 rows
#            m5 = 0.9416986725000003  ->  1 rows
#            m5 = 0.9428516730000003  ->  1 rows
#            m5 = 0.9445151928  ->  1 rows
#            m5 = 0.94460497725  ->  1 rows
#            m5 = 0.9449384475000002  ->  1 rows
#            m5 = 0.9451182224999988  ->  1 rows
#            m5 = 0.9457206525000013  ->  1 rows
#            m5 = 0.9482149124999997  ->  1 rows
#            m5 = 0.9498878699999995  ->  1 rows
#            m5 = 0.9507984750000009  ->  1 rows
#            m5 = 0.95102984925  ->  1 rows
#            m5 = 0.951319869  ->  1 rows
#            m5 = 0.9525820395  ->  1 rows
#            m5 = 0.9579731407500003  ->  1 rows
#            m5 = 0.9582904874999993  ->  1 rows
#            m5 = 0.9583475325000004  ->  1 rows
#            m5 = 0.9599583652499999  ->  1 rows
#            m5 = 0.9633774929999994  ->  1 rows
#            m5 = 0.9635248512  ->  1 rows
#            m5 = 0.9653803725000003  ->  1 rows
#            m5 = 0.9673900447499997  ->  1 rows
#            m5 = 0.9678361664999999  ->  1 rows
#            m5 = 0.9681015675  ->  1 rows
#            m5 = 0.9682170750000001  ->  1 rows
#            m5 = 0.9692454750000001  ->  1 rows
#            m5 = 0.9696046575000001  ->  1 rows
#            m5 = 0.9731315039999999  ->  1 rows
#            m5 = 0.9731882715  ->  1 rows
#            m5 = 0.9750149640000001  ->  1 rows
#            m5 = 0.9764525556  ->  1 rows
#            m5 = 0.9785304443999999  ->  1 rows
#            m5 = 0.97892605575  ->  1 rows
#            m5 = 0.9790799782499999  ->  1 rows
#            m5 = 0.9812555324999996  ->  1 rows
#            m5 = 0.9850463377499998  ->  1 rows
#            m5 = 0.9872366250000002  ->  1 rows
#            m5 = 0.9896073952500006  ->  1 rows
#            m5 = 0.9900950370000001  ->  1 rows
#            m5 = 0.9909874859999999  ->  1 rows
#            m5 = 0.99179128875  ->  1 rows
#            m5 = 0.9954617827499996  ->  1 rows
#            m5 = 0.99564786  ->  1 rows
#            m5 = 0.996624477  ->  1 rows
#            m5 = 0.9967063462500003  ->  1 rows
#            m5 = 0.9984507857999998  ->  1 rows
#            m5 = 0.9998137817999998  ->  1 rows
#            m5 = 0.9999114495000001  ->  1 rows
#            m5 = 1.002708297  ->  1 rows
#            m5 = 1.0048438874999999  ->  1 rows
#            m5 = 1.0054850654999998  ->  1 rows
#            m5 = 1.0058348226  ->  1 rows
#            m5 = 1.0059844282500001  ->  1 rows
#            m5 = 1.0061236350000002  ->  1 rows
#            m5 = 1.0070826825000003  ->  1 rows
#            m5 = 1.0075925534999999  ->  1 rows
#            m5 = 1.0076314687499999  ->  1 rows
#            m5 = 1.008105825  ->  1 rows
#            m5 = 1.009258290000001  ->  1 rows
#            m5 = 1.0115340374999997  ->  1 rows
#            m5 = 1.0129195425000006  ->  1 rows
#            m5 = 1.0135644337500005  ->  1 rows
#            m5 = 1.0137004649999994  ->  1 rows
#            m5 = 1.0145231430000001  ->  1 rows
#            m5 = 1.0171285800000005  ->  1 rows
#            m5 = 1.0185226875000004  ->  1 rows
#            m5 = 1.0191786354  ->  1 rows
#            m5 = 1.0200105164999997  ->  1 rows
#            m5 = 1.0236403972499997  ->  1 rows
#            m5 = 1.02548782275  ->  1 rows
#            m5 = 1.0275444465  ->  1 rows
#            m5 = 1.02842064225  ->  1 rows
#            m5 = 1.0284378824999996  ->  1 rows
#            m5 = 1.0309919474999996  ->  1 rows
#            m5 = 1.0335530646  ->  1 rows
#            m5 = 1.03384832025  ->  1 rows
#            m5 = 1.0341091845000001  ->  1 rows
#            m5 = 1.0360166442  ->  1 rows
#            m5 = 1.0367397974999992  ->  1 rows
#            m5 = 1.0379617425000003  ->  1 rows
#            m5 = 1.04012999625  ->  1 rows
#            m5 = 1.0404716632500002  ->  1 rows
#            m5 = 1.0427347823999997  ->  1 rows
#            m5 = 1.0447338502500005  ->  1 rows
#            m5 = 1.0447668375  ->  1 rows
#            m5 = 1.0455702405  ->  1 rows
#            m5 = 1.0476376275000003  ->  1 rows
#            m5 = 1.0476573037500003  ->  1 rows
#            m5 = 1.0487102849999994  ->  1 rows
#            m5 = 1.0516019325000001  ->  1 rows
#            m5 = 1.0529191275000005  ->  1 rows
#            m5 = 1.05431421075  ->  1 rows
#            m5 = 1.0562021407499995  ->  1 rows
#            m5 = 1.0569747389999997  ->  1 rows
#            m5 = 1.0570687665000005  ->  1 rows
#            m5 = 1.0589345024999997  ->  1 rows
#            m5 = 1.062078787499999  ->  1 rows
#            m5 = 1.0626937505999998  ->  1 rows
#            m5 = 1.0638241695000001  ->  1 rows
#            m5 = 1.0640630988  ->  1 rows
#            m5 = 1.0643705099999994  ->  1 rows
#            m5 = 1.0649172299999994  ->  1 rows
#            m5 = 1.065725043  ->  1 rows
#            m5 = 1.0668984396000003  ->  1 rows
#            m5 = 1.0670147767499993  ->  1 rows
#            m5 = 1.0688410332  ->  1 rows
#            m5 = 1.0722929238000003  ->  1 rows
#            m5 = 1.0729168200000005  ->  1 rows
#            m5 = 1.0741786814999998  ->  1 rows
#            m5 = 1.0742650374000002  ->  1 rows
#            m5 = 1.0763779499999995  ->  1 rows
#            m5 = 1.0767079335000003  ->  1 rows
#            m5 = 1.076906289  ->  1 rows
#            m5 = 1.0775919577500006  ->  1 rows
#            m5 = 1.078318371  ->  1 rows
#            m5 = 1.07972905575  ->  1 rows
#            m5 = 1.08039998625  ->  1 rows
#            m5 = 1.08773244525  ->  1 rows
#            m5 = 1.0879402985999997  ->  1 rows
#            m5 = 1.0885269225000007  ->  1 rows
#            m5 = 1.0892695499999991  ->  1 rows
#            m5 = 1.0937827109999998  ->  1 rows
#            m5 = 1.0974757237500001  ->  1 rows
#            m5 = 1.1003503057499997  ->  1 rows
#            m5 = 1.1026241520000002  ->  1 rows
#            m5 = 1.1029689000000005  ->  1 rows
#            m5 = 1.10372230725  ->  1 rows
#            m5 = 1.1049938114999998  ->  1 rows
#            m5 = 1.1050684943999998  ->  1 rows
#            m5 = 1.1053569467999997  ->  1 rows
#            m5 = 1.1060295449999993  ->  1 rows
#            m5 = 1.1067157073999998  ->  1 rows
#            m5 = 1.1073821166  ->  1 rows
#            m5 = 1.1092427377499994  ->  1 rows
#            m5 = 1.1097607515  ->  1 rows
#            m5 = 1.11029985375  ->  1 rows
#            m5 = 1.1106433792499997  ->  1 rows
#            m5 = 1.1119913819999998  ->  1 rows
#            m5 = 1.1123913299999995  ->  1 rows
#            m5 = 1.1131880752499999  ->  1 rows
#            m5 = 1.11340673775  ->  1 rows
#            m5 = 1.1154537299999996  ->  1 rows
#            m5 = 1.1212348132500005  ->  1 rows
#            m5 = 1.1213677005  ->  1 rows
#            m5 = 1.1227327575  ->  1 rows
#            m5 = 1.12308056175  ->  1 rows
#            m5 = 1.1232763739999998  ->  1 rows
#            m5 = 1.123621365  ->  1 rows
#            m5 = 1.1237848079999995  ->  1 rows
#            m5 = 1.1244837555000002  ->  1 rows
#            m5 = 1.1245055759999998  ->  1 rows
#            m5 = 1.1250763275000004  ->  1 rows
#            m5 = 1.12593470775  ->  1 rows
#            m5 = 1.1274364349999995  ->  1 rows
#            m5 = 1.1282988517499999  ->  1 rows
#            m5 = 1.1322570930000002  ->  1 rows
#            m5 = 1.1324977968  ->  1 rows
#            m5 = 1.1348187534  ->  1 rows
#            m5 = 1.13599256175  ->  1 rows
#            m5 = 1.13604459975  ->  1 rows
#            m5 = 1.1367867150000013  ->  1 rows
#            m5 = 1.1388575400000003  ->  1 rows
#            m5 = 1.1407679092499996  ->  1 rows
#            m5 = 1.14107868525  ->  1 rows
#            m5 = 1.1456525324999998  ->  1 rows
#            m5 = 1.1522048909999998  ->  1 rows
#            m5 = 1.1550918952499996  ->  1 rows
#            m5 = 1.1551793850000003  ->  1 rows
#            m5 = 1.1566954754999998  ->  1 rows
#            m5 = 1.1579866739999998  ->  1 rows
#            m5 = 1.157997252  ->  1 rows
#            m5 = 1.1595928575000007  ->  1 rows
#            m5 = 1.1602845246  ->  1 rows
#            m5 = 1.1619742425000004  ->  1 rows
#            m5 = 1.1621196545999999  ->  1 rows
#            m5 = 1.1623424478  ->  1 rows
#            m5 = 1.1629598442000002  ->  1 rows
#            m5 = 1.16334899325  ->  1 rows
#            m5 = 1.1656796355  ->  1 rows
#            m5 = 1.1657104875  ->  1 rows
#            m5 = 1.1672875874999988  ->  1 rows
#            m5 = 1.1689069934999998  ->  1 rows
#            m5 = 1.16925104175  ->  1 rows
#            m5 = 1.1696163525  ->  1 rows
#            m5 = 1.1724804495000005  ->  1 rows
#            m5 = 1.1750074425  ->  1 rows
#            m5 = 1.1750156317500002  ->  1 rows
#            m5 = 1.1764928454  ->  1 rows
#            m5 = 1.1766274440000002  ->  1 rows
#            m5 = 1.1772359362499993  ->  1 rows
#            m5 = 1.1772877200000007  ->  1 rows
#            m5 = 1.17877759275  ->  1 rows
#            m5 = 1.1824199565  ->  1 rows
#            m5 = 1.1839315424999994  ->  1 rows
#            m5 = 1.1854043850000004  ->  1 rows
#            m5 = 1.1869943423999998  ->  1 rows
#            m5 = 1.187316264  ->  1 rows
#            m5 = 1.1891247804000002  ->  1 rows
#            m5 = 1.1891795684999997  ->  1 rows
#            m5 = 1.1892493854  ->  1 rows
#            m5 = 1.1895371212499999  ->  1 rows
#            m5 = 1.1899652782500003  ->  1 rows
#            m5 = 1.1911236645  ->  1 rows
#            m5 = 1.1916852045  ->  1 rows
#            m5 = 1.1918121599999996  ->  1 rows
#            m5 = 1.1938287705000001  ->  1 rows
#            m5 = 1.1946214584000001  ->  1 rows
#            m5 = 1.1953013189999995  ->  1 rows
#            m5 = 1.1954252002500003  ->  1 rows
#            m5 = 1.1965469662500001  ->  1 rows
#            m5 = 1.1975475696  ->  1 rows
#            m5 = 1.1982166446  ->  1 rows
#            m5 = 1.1990896582500001  ->  1 rows
#            m5 = 1.199201145  ->  1 rows
#            m5 = 1.19978936925  ->  1 rows
#            m5 = 1.2014169534  ->  1 rows
#            m5 = 1.2025815618  ->  1 rows
#            m5 = 1.20304300725  ->  1 rows
#            m5 = 1.2049073376000001  ->  1 rows
#            m5 = 1.2056000685  ->  1 rows
#            m5 = 1.2068735024999988  ->  1 rows
#            m5 = 1.2082053494999998  ->  1 rows
#            m5 = 1.2087702554999997  ->  1 rows
#            m5 = 1.20935274  ->  1 rows
#            m5 = 1.2093589275000003  ->  1 rows
#            m5 = 1.2101738886000002  ->  1 rows
# ...
#            m5 = 2.5328290575000003  ->  1 rows
#            m5 = 2.53476614325  ->  1 rows
#            m5 = 2.5364563875000004  ->  1 rows
#            m5 = 2.5369335224999996  ->  1 rows
#            m5 = 2.537124300000001  ->  1 rows
#            m5 = 2.53903234425  ->  1 rows
#            m5 = 2.5394154374999998  ->  1 rows
#            m5 = 2.5428171975  ->  1 rows
#            m5 = 2.542898407499999  ->  1 rows
#            m5 = 2.5435635449999996  ->  1 rows
#            m5 = 2.5450152551999996  ->  1 rows
#            m5 = 2.5460010375  ->  1 rows
#            m5 = 2.5472423925000003  ->  1 rows
#            m5 = 2.5486416975  ->  1 rows
#            m5 = 2.5492807200000005  ->  1 rows
#            m5 = 2.54940093825  ->  1 rows
#            m5 = 2.55093094275  ->  1 rows
#            m5 = 2.5538232405  ->  1 rows
#            m5 = 2.55689293425  ->  1 rows
#            m5 = 2.5596186974999995  ->  1 rows
#            m5 = 2.559774494999999  ->  1 rows
#            m5 = 2.5661099775  ->  1 rows
#            m5 = 2.5670506425  ->  1 rows
#            m5 = 2.567785851  ->  1 rows
#            m5 = 2.5696704282  ->  1 rows
#            m5 = 2.56973630775  ->  1 rows
#            m5 = 2.5698037725  ->  1 rows
#            m5 = 2.57000037675  ->  1 rows
#            m5 = 2.57025364425  ->  1 rows
#            m5 = 2.5718077949999993  ->  1 rows
#            m5 = 2.57281782075  ->  1 rows
#            m5 = 2.573204925  ->  1 rows
#            m5 = 2.5735525575  ->  1 rows
#            m5 = 2.5740764895000003  ->  1 rows
#            m5 = 2.5780838175000005  ->  1 rows
#            m5 = 2.5784693268000005  ->  1 rows
#            m5 = 2.57894183325  ->  1 rows
#            m5 = 2.5792665225  ->  1 rows
#            m5 = 2.5794602831999995  ->  1 rows
#            m5 = 2.58018661725  ->  1 rows
#            m5 = 2.582749125000001  ->  1 rows
#            m5 = 2.5840707210000002  ->  1 rows
#            m5 = 2.585080177500001  ->  1 rows
#            m5 = 2.5917813845999995  ->  1 rows
#            m5 = 2.5960621874999994  ->  1 rows
#            m5 = 2.59775189775  ->  1 rows
#            m5 = 2.5987404618  ->  1 rows
#            m5 = 2.5991791732500005  ->  1 rows
#            m5 = 2.5999273875000006  ->  1 rows
#            m5 = 2.6010391350000006  ->  1 rows
#            m5 = 2.6067885876  ->  1 rows
#            m5 = 2.607689967  ->  1 rows
#            m5 = 2.6079515616  ->  1 rows
#            m5 = 2.6083047269999997  ->  1 rows
#            m5 = 2.6115733665  ->  1 rows
#            m5 = 2.6123331825000005  ->  1 rows
#            m5 = 2.6129006400000003  ->  1 rows
#            m5 = 2.6129798925000003  ->  1 rows
#            m5 = 2.6154057900000005  ->  1 rows
#            m5 = 2.6171684737500005  ->  1 rows
#            m5 = 2.6172143774999994  ->  1 rows
#            m5 = 2.617498252500001  ->  1 rows
#            m5 = 2.6184177525  ->  1 rows
#            m5 = 2.6189437424999995  ->  1 rows
#            m5 = 2.61958297125  ->  1 rows
#            m5 = 2.62060302  ->  1 rows
#            m5 = 2.6214631424999997  ->  1 rows
#            m5 = 2.6229040274999997  ->  1 rows
#            m5 = 2.6236887599999994  ->  1 rows
#            m5 = 2.6236967831999998  ->  1 rows
#            m5 = 2.62512951  ->  1 rows
#            m5 = 2.6257074975  ->  1 rows
#            m5 = 2.6262855900000006  ->  1 rows
#            m5 = 2.6296176307500003  ->  1 rows
#            m5 = 2.6298686774999998  ->  1 rows
#            m5 = 2.6299149382500002  ->  1 rows
#            m5 = 2.629934715  ->  1 rows
#            m5 = 2.6312621562000005  ->  1 rows
#            m5 = 2.6331210198  ->  1 rows
#            m5 = 2.6334725774999996  ->  1 rows
#            m5 = 2.6335222199999997  ->  1 rows
#            m5 = 2.6339662350000004  ->  1 rows
#            m5 = 2.6365287225000005  ->  1 rows
#            m5 = 2.6382081599999996  ->  1 rows
#            m5 = 2.640422292  ->  1 rows
#            m5 = 2.64131637375  ->  1 rows
#            m5 = 2.64372375  ->  1 rows
#            m5 = 2.6438615924999995  ->  1 rows
#            m5 = 2.6455119299999996  ->  1 rows
#            m5 = 2.64840497325  ->  1 rows
#            m5 = 2.6495929794  ->  1 rows
#            m5 = 2.6531086800000003  ->  1 rows
#            m5 = 2.6537144925000002  ->  1 rows
#            m5 = 2.654574825  ->  1 rows
#            m5 = 2.654620188  ->  1 rows
#            m5 = 2.65529784975  ->  1 rows
#            m5 = 2.6560648725000005  ->  1 rows
#            m5 = 2.6562476085  ->  1 rows
#            m5 = 2.6564504145  ->  1 rows
#            m5 = 2.6565487314  ->  1 rows
#            m5 = 2.6594817825000003  ->  1 rows
#            m5 = 2.6608666560000005  ->  1 rows
#            m5 = 2.662495041  ->  1 rows
#            m5 = 2.6655825149999997  ->  1 rows
#            m5 = 2.667172334999999  ->  1 rows
#            m5 = 2.66798987325  ->  1 rows
#            m5 = 2.6683778699999987  ->  1 rows
#            m5 = 2.66983875825  ->  1 rows
#            m5 = 2.6724330075  ->  1 rows
#            m5 = 2.6745997425  ->  1 rows
#            m5 = 2.676708645  ->  1 rows
#            m5 = 2.6771524349999996  ->  1 rows
#            m5 = 2.6772103380000005  ->  1 rows
#            m5 = 2.6775172725  ->  1 rows
#            m5 = 2.67784565175  ->  1 rows
#            m5 = 2.6783319000000003  ->  1 rows
#            m5 = 2.678502753  ->  1 rows
#            m5 = 2.6882892524999997  ->  1 rows
#            m5 = 2.6889689699999995  ->  1 rows
#            m5 = 2.6902723313999997  ->  1 rows
#            m5 = 2.6930901525000004  ->  1 rows
#            m5 = 2.6950219575  ->  1 rows
#            m5 = 2.6950565249999996  ->  1 rows
#            m5 = 2.69744259  ->  1 rows
#            m5 = 2.6983548375  ->  1 rows
#            m5 = 2.6986956696  ->  1 rows
#            m5 = 2.698712949  ->  1 rows
#            m5 = 2.699127126  ->  1 rows
#            m5 = 2.7003720375  ->  1 rows
#            m5 = 2.7009347325000004  ->  1 rows
#            m5 = 2.7009411375  ->  1 rows
#            m5 = 2.7028164525000005  ->  1 rows
#            m5 = 2.7035005050000005  ->  1 rows
#            m5 = 2.7035073524999995  ->  1 rows
#            m5 = 2.7044749799999988  ->  1 rows
#            m5 = 2.7066299797499997  ->  1 rows
#            m5 = 2.7070205999999994  ->  1 rows
#            m5 = 2.7080803874999995  ->  1 rows
#            m5 = 2.7093681749999994  ->  1 rows
#            m5 = 2.711140875  ->  1 rows
#            m5 = 2.7118176900000006  ->  1 rows
#            m5 = 2.7122194649999996  ->  1 rows
#            m5 = 2.712538203  ->  1 rows
#            m5 = 2.71396222125  ->  1 rows
#            m5 = 2.7154605675  ->  1 rows
#            m5 = 2.718424338  ->  1 rows
#            m5 = 2.7210715499999996  ->  1 rows
#            m5 = 2.730694545  ->  1 rows
#            m5 = 2.7313547624999996  ->  1 rows
#            m5 = 2.731615245  ->  1 rows
#            m5 = 2.7318045288  ->  1 rows
#            m5 = 2.7332890139999995  ->  1 rows
#            m5 = 2.736526275  ->  1 rows
#            m5 = 2.736985122  ->  1 rows
#            m5 = 2.7375845399999994  ->  1 rows
#            m5 = 2.7386055870000003  ->  1 rows
#            m5 = 2.7386653787999995  ->  1 rows
#            m5 = 2.7388171725  ->  1 rows
#            m5 = 2.73898124325  ->  1 rows
#            m5 = 2.7392663099999996  ->  1 rows
#            m5 = 2.7414767025  ->  1 rows
#            m5 = 2.7435621524999996  ->  1 rows
#            m5 = 2.7435784949999995  ->  1 rows
#            m5 = 2.7441630504  ->  1 rows
#            m5 = 2.748962985  ->  1 rows
#            m5 = 2.7494369475000004  ->  1 rows
#            m5 = 2.750271  ->  1 rows
#            m5 = 2.7603687299999997  ->  1 rows
#            m5 = 2.7604985399999995  ->  1 rows
#            m5 = 2.7619838775000005  ->  1 rows
#            m5 = 2.7625603050000005  ->  1 rows
#            m5 = 2.7639439125000003  ->  1 rows
#            m5 = 2.76649646175  ->  1 rows
#            m5 = 2.7700593719999995  ->  1 rows
#            m5 = 2.77040665125  ->  1 rows
#            m5 = 2.7704194424999997  ->  1 rows
#            m5 = 2.7705255675000005  ->  1 rows
#            m5 = 2.7740624775  ->  1 rows
#            m5 = 2.77581651  ->  1 rows
#            m5 = 2.7777153074999994  ->  1 rows
#            m5 = 2.77881203925  ->  1 rows
#            m5 = 2.77881339  ->  1 rows
#            m5 = 2.77905099  ->  1 rows
#            m5 = 2.78072629875  ->  1 rows
#            m5 = 2.7813626714999997  ->  1 rows
#            m5 = 2.7822262574999996  ->  1 rows
#            m5 = 2.782444072499999  ->  1 rows
#            m5 = 2.7831810015  ->  1 rows
#            m5 = 2.7832349250000012  ->  1 rows
#            m5 = 2.7836194499999998  ->  1 rows
#            m5 = 2.7838773750000003  ->  1 rows
#            m5 = 2.7852312300000004  ->  1 rows
#            m5 = 2.7864053774999995  ->  1 rows
#            m5 = 2.7885635324999996  ->  1 rows
#            m5 = 2.7889430542499998  ->  1 rows
#            m5 = 2.7890159175  ->  1 rows
#            m5 = 2.7909142044  ->  1 rows
#            m5 = 2.7929786550000006  ->  1 rows
#            m5 = 2.79304386825  ->  1 rows
#            m5 = 2.7932734575000002  ->  1 rows
#            m5 = 2.7937474199999994  ->  1 rows
#            m5 = 2.794870627499999  ->  1 rows
#            m5 = 2.7970165800000006  ->  1 rows
#            m5 = 2.7974398635  ->  1 rows
#            m5 = 2.7982527705  ->  1 rows
#            m5 = 2.8021495875000006  ->  1 rows
#            m5 = 2.8047822450000006  ->  1 rows
#            m5 = 2.8056774547499996  ->  1 rows
#            m5 = 2.806074228  ->  1 rows
#            m5 = 2.80870423425  ->  1 rows
#            m5 = 2.810438757  ->  1 rows
#            m5 = 2.8107496875  ->  1 rows
#            m5 = 2.8121899627499998  ->  1 rows
#            m5 = 2.8133074349999996  ->  1 rows
#            m5 = 2.8136396624999995  ->  1 rows
#            m5 = 2.8136558928000004  ->  1 rows
#            m5 = 2.8159433325  ->  1 rows
#            m5 = 2.81711666325  ->  1 rows
#            m5 = 2.8180840087499996  ->  1 rows
#            m5 = 2.819495001  ->  1 rows
#            m5 = 2.819568314999999  ->  1 rows
#            m5 = 2.8222843214999997  ->  1 rows
#            m5 = 2.82431826  ->  1 rows
#            m5 = 2.82695011725  ->  1 rows
#            m5 = 2.82725662725  ->  1 rows
#            m5 = 2.8276549282500003  ->  1 rows
#            m5 = 2.8346280202500003  ->  1 rows
#            m5 = 2.8351626449999996  ->  1 rows
#            m5 = 2.836445662499999  ->  1 rows
#            m5 = 2.837577954  ->  1 rows
#            m5 = 2.8387759275000004  ->  1 rows
#            m5 = 2.839001174999999  ->  1 rows
#            m5 = 2.8400234040000005  ->  1 rows
#            m5 = 2.8404696375  ->  1 rows
#            m5 = 2.8438339665  ->  1 rows
#            m5 = 2.8445437874999997  ->  1 rows
#            m5 = 2.84534574  ->  1 rows
#            m5 = 2.8457443536  ->  1 rows
#            m5 = 2.84616275475  ->  1 rows
#            m5 = 2.8465656825000005  ->  1 rows
#            m5 = 2.8482524507999996  ->  1 rows
#            m5 = 2.848975008  ->  1 rows
#            m5 = 2.8512098567999993  ->  1 rows
#            m5 = 2.8514113455  ->  1 rows
#            m5 = 2.8544532359999994  ->  1 rows
#            m5 = 2.85469818825  ->  1 rows
#            m5 = 2.8556178450000003  ->  1 rows
#            m5 = 2.856559215  ->  1 rows
#            m5 = 2.8576764750000003  ->  1 rows
#            m5 = 2.8588545165  ->  1 rows
#            m5 = 2.85891405825  ->  1 rows
#            m5 = 2.8596787650000004  ->  1 rows
#            m5 = 2.8639824450000013  ->  1 rows
#            m5 = 2.8642343999999995  ->  1 rows
#            m5 = 2.86553216625  ->  1 rows
#            m5 = 2.8665965715  ->  1 rows
#            m5 = 2.8667205972  ->  1 rows
#            m5 = 2.8668838499999993  ->  1 rows
#            m5 = 2.8671744825000003  ->  1 rows
#            m5 = 2.8679701574999994  ->  1 rows
#            m5 = 2.8680516255  ->  1 rows
#            m5 = 2.86827247575  ->  1 rows
#            m5 = 2.86947504  ->  1 rows
#            m5 = 2.8701075449999998  ->  1 rows
#            m5 = 2.8702700805  ->  1 rows
#            m5 = 2.870859966  ->  1 rows
#            m5 = 2.872966065  ->  1 rows
#            m5 = 2.8739095185  ->  1 rows
#            m5 = 2.8753421024999994  ->  1 rows
#            m5 = 2.875627962  ->  1 rows
#            m5 = 2.876334742499999  ->  1 rows
#            m5 = 2.8774158150000004  ->  1 rows
#            m5 = 2.87776714275  ->  1 rows
#            m5 = 2.8777779450000005  ->  1 rows
#            m5 = 2.8786372836000003  ->  1 rows
#            m5 = 2.87897826  ->  1 rows
#            m5 = 2.880320895  ->  1 rows
#            m5 = 2.8810207957499996  ->  1 rows
#            m5 = 2.883303429  ->  1 rows
#            m5 = 2.88668408025  ->  1 rows
#            m5 = 2.886976184999999  ->  1 rows
#            m5 = 2.8880710499999998  ->  1 rows
#            m5 = 2.8898212124999993  ->  1 rows
#            m5 = 2.8915607925  ->  1 rows
#            m5 = 2.89427453775  ->  1 rows
#            m5 = 2.8951205475000004  ->  1 rows
#            m5 = 2.895190875  ->  1 rows
#            m5 = 2.896084107  ->  1 rows
#            m5 = 2.8966103625  ->  1 rows
#            m5 = 2.898470931  ->  1 rows
#            m5 = 2.901776085  ->  1 rows
#            m5 = 2.9039604824999996  ->  1 rows
#            m5 = 2.9078889750000005  ->  1 rows
#            m5 = 2.9091607949999996  ->  1 rows
#            m5 = 2.9112306525  ->  1 rows
#            m5 = 2.9155346475000004  ->  1 rows
#            m5 = 2.916452685000001  ->  1 rows
#            m5 = 2.9185781232  ->  1 rows
#            m5 = 2.9214147862499997  ->  1 rows
#            m5 = 2.92224049875  ->  1 rows
#            m5 = 2.923412902500001  ->  1 rows
#            m5 = 2.92517505  ->  1 rows
#            m5 = 2.9264465625  ->  1 rows
#            m5 = 2.9318700645  ->  1 rows
#            m5 = 2.9323128929999998  ->  1 rows
#            m5 = 2.9331864102000003  ->  1 rows
#            m5 = 2.9340475674  ->  1 rows
#            m5 = 2.9341338749999997  ->  1 rows
#            m5 = 2.9342347553999995  ->  1 rows
#            m5 = 2.9363655555  ->  1 rows
#            m5 = 2.9365624822500003  ->  1 rows
#            m5 = 2.93809811925  ->  1 rows
#            m5 = 2.9382650774999997  ->  1 rows
#            m5 = 2.9395613925000004  ->  1 rows
#            m5 = 2.9419708199999994  ->  1 rows
#            m5 = 2.94495980625  ->  1 rows
#            m5 = 2.94608951475  ->  1 rows
#            m5 = 2.946211302  ->  1 rows
#            m5 = 2.94707476275  ->  1 rows
#            m5 = 2.9524233225000005  ->  1 rows
#            m5 = 2.9528889922499997  ->  1 rows
#            m5 = 2.9542682549999997  ->  1 rows
#            m5 = 2.9545215464999997  ->  1 rows
#            m5 = 2.9547210225  ->  1 rows
#            m5 = 2.956704509999999  ->  1 rows
#            m5 = 2.9575165799999996  ->  1 rows
#            m5 = 2.9577304274999996  ->  1 rows
#            m5 = 2.9580771599999993  ->  1 rows
#            m5 = 2.95824999  ->  1 rows
#            m5 = 2.9593649925000003  ->  1 rows
#            m5 = 2.961040605  ->  1 rows
#            m5 = 2.9611457940000006  ->  1 rows
#            m5 = 2.9613141071999998  ->  1 rows
#            m5 = 2.9625375524999997  ->  1 rows
#            m5 = 2.9655696419999997  ->  1 rows
#            m5 = 2.9661663149999997  ->  1 rows
#            m5 = 2.9673206775000005  ->  1 rows
#            m5 = 2.9687528775  ->  1 rows
#            m5 = 2.9693507324999997  ->  1 rows
#            m5 = 2.9697395025000004  ->  1 rows
#            m5 = 2.9719924500000006  ->  1 rows
#            m5 = 2.9735615645999998  ->  1 rows
#            m5 = 2.97469701  ->  1 rows
#            m5 = 2.975684145  ->  1 rows
#            m5 = 2.9771893199999995  ->  1 rows
#            m5 = 2.9773888057500004  ->  1 rows
#            m5 = 2.9798087774999997  ->  1 rows
#            m5 = 2.98123963875  ->  1 rows
#            m5 = 2.9817341309999996  ->  1 rows
#            m5 = 2.9818827246  ->  1 rows
#            m5 = 2.9839202495999992  ->  1 rows
#            m5 = 2.9878735991999994  ->  1 rows
#            m5 = 2.9884974924  ->  1 rows
#            m5 = 2.990392044  ->  1 rows
#            m5 = 2.991158819999999  ->  1 rows
#            m5 = 2.9914328745  ->  1 rows
#            m5 = 2.9948163750000005  ->  1 rows
#            m5 = 2.9950398371999998  ->  1 rows
#            m5 = 2.9980290675000005  ->  1 rows
#            m5 = 2.9986689375000006  ->  1 rows
#   ALL CHECKS PASSED
#   rules are usable — proceed with training

# %%
#apply rules ONLY on training set, ensure test still has hidden column
train_df = apply_rules(train_df, rules)
test_df = ensure_hidden_column(test_df, rules)   # keep structure consistent

# %%
#identify hidden variable and split labeled/unlabeled (train only)
hidden_var = list(rules["variables"].keys())[0]   # general: first hidden variable
labeled_rows = train_df[train_df[hidden_var].notna()]
unlabeled_rows = train_df[train_df[hidden_var].isna()]

print("Train total:", len(train_df))
print("Labeled (rule rows):", len(labeled_rows))
print("Unlabeled:", len(unlabeled_rows))

# FIX: Save a clean snapshot of train_df BEFORE h-recovery
# Baselines must impute h themselves from this clean copy
train_df_clean = train_df.copy()
# Out:
# Train total: 8000
# Labeled (rule rows): 2394
# Unlabeled: 5606

# %%
# select numeric features automatically (general)

target = "target"

numeric_cols = list(train_df.select_dtypes(include=[np.number]).columns)

# ✅ KEEP hidden_var (this is the key fix)
features = [c for c in numeric_cols if c not in [target, "is_rule"]]

print("Features used for base model:", features)
# Out:
# Features used for base model: ['m1', 'm2', 'm3', 'm4', 'laser', 'm5']

# %%
# initialize weights, bias, hyperparams

n_features = len(features)

# small random initialization
weights = np.random.randn(n_features) * 0.01
bias = 0.0

# hyperparameters from CONFIG
learning_rate = CONFIG["learning_rate"]
epochs = CONFIG["epochs"]
batch_size = CONFIG["batch_size"]

# %%
#loss calculator
def predict(X, weights, bias):  
    
    return np.dot(X, weights) + bias


def mse_loss(y_true, y_pred):
    """
    Compute Mean Squared Error loss."""
    return np.mean((y_true - y_pred)**2)

# %%
# train ONLY on rows where hidden_var is known
train_labeled = train_df[train_df[hidden_var].notna()]

X_train = train_labeled[features].values.astype(float)
y_train = train_labeled[target].values.astype(float)

# ---------- NORMALIZATION (MANDATORY) ----------
X_mean = X_train.mean(axis=0)
X_std = X_train.std(axis=0)
X_std[X_std == 0] = 1.0

X_train = (X_train - X_mean) / X_std

y_mean = y_train.mean()
y_std = y_train.std()
y_train = (y_train - y_mean) / y_std
# ----------------------------------------------

batch_size = min(batch_size, len(X_train))
loss_history = [] 

for epoch in range(epochs):

    perm = np.random.permutation(len(X_train))
    X_sh = X_train[perm]
    y_sh = y_train[perm]

    for i in range(0, len(X_sh), batch_size):

        X_batch = X_sh[i:i+batch_size]
        y_batch = y_sh[i:i+batch_size]

        y_pred = predict(X_batch, weights, bias)
        error = y_pred - y_batch

        dw = (2.0 / len(y_batch)) * np.dot(X_batch.T, error)
        db = (2.0 / len(y_batch)) * np.sum(error)

        # ---------- GRADIENT CLIPPING ----------
        dw = np.clip(dw, -1, 1)
        db = np.clip(db, -1, 1)
        # --------------------------------------

        weights -= learning_rate * dw
        bias -= learning_rate * db

    if epoch % 50 == 0:
        loss = mse_loss(y_train, predict(X_train, weights, bias))
        loss_history.append(loss)   
        print(f"Epoch {epoch:04d} loss: {loss:.6f}")
# Out:
# Epoch 0000 loss: 0.853744
# Epoch 0050 loss: 0.471772
# Epoch 0100 loss: 0.471717
# Epoch 0150 loss: 0.471716
# Epoch 0200 loss: 0.471716
# Epoch 0250 loss: 0.471716

# %%
# estimate hidden on unlabeled train rows (your method)

unlabeled_rows = train_df[train_df[hidden_var].isna()].copy()

if len(unlabeled_rows) > 0:

    feature_index = {f: i for i, f in enumerate(features)}

    # 🔒 safety check
    if hidden_var not in feature_index:
        raise ValueError(
            f"{hidden_var} not found in features.\n"
            f"Current features: {features}\n"
            f"👉 You must include hidden_var in features before training."
        )

    hidden_idx = feature_index[hidden_var]
    w_hidden = weights[hidden_idx]

    # Step 1 — base prediction (set hidden = 0)
    X_unlabeled = unlabeled_rows[features].copy()
    X_unlabeled[hidden_var] = 0

    X_raw_unl = X_unlabeled.values.astype(float)

    # safe normalization
    X_std_safe = np.where(X_std == 0, 1.0, X_std)
    X_norm_unl = (X_raw_unl - X_mean) / X_std_safe

    base_pred = predict(X_norm_unl, weights, bias)

    # convert to real scale
    base_pred_real = base_pred * y_std + y_mean

    # Step 2 — convert hidden weight to real scale
    if X_std_safe[hidden_idx] == 0:
        print("⚠️ hidden feature std is zero → unstable scaling")
        w_hidden_real = 1e-8
    else:
        w_hidden_real = w_hidden * (y_std / X_std_safe[hidden_idx])

    # safety check for near-zero weight
    epsilon = 1e-8
    if abs(w_hidden_real) < epsilon:
        print("⚠️ Hidden weight too small — unstable recovery")
        w_hidden_real = epsilon

    # Step 3 — solve for hidden
    hidden_est = (unlabeled_rows[target].values - base_pred_real) / w_hidden_real

    # Step 4 — clip to valid range
    low, high = rules["variables"][hidden_var]["range"]
    hidden_est = np.clip(hidden_est, low, high)

    # Step 5 — write back
    train_df.loc[unlabeled_rows.index, hidden_var] = hidden_est

    print(f"Filled {len(hidden_est)} unlabeled train rows.")
    print(f"Recovered range: [{hidden_est.min():.4f}, {hidden_est.max():.4f}]")
    print(f"Expected range: [{low}, {high}]")

else:
    print("No unlabeled rows.")
# Out:
# Filled 5606 unlabeled train rows.
# Recovered range: [0.0000, 3.0000]
# Expected range: [0, 3]

# %%
# 1. Rebuild feature list
numeric_cols = list(train_df.select_dtypes(include=[np.number]).columns)
features_all = [c for c in numeric_cols if c != target]

# 2. Prepare X and y
X_raw = train_df[features_all].values.astype(float)
y_final = train_df[target].values.astype(float)

# Normalize y 
y_mean_final = y_final.mean()
y_std_final  = y_final.std()
if y_std_final == 0:
    y_std_final = 1.0
y_scaled = (y_final - y_mean_final) / y_std_final

# 3. Feature Scaling
X_mean_final = np.mean(X_raw, axis=0)
X_std_final  = np.std(X_raw, axis=0)
X_std_final[X_std_final == 0] = 1.0
X_final = (X_raw - X_mean_final) / X_std_final

# 4. Initialize or remap weights to match features_all length
if 'weights' not in locals() or len(weights) != len(features_all):
    new_w = np.random.randn(len(features_all)) * 0.01
    if 'weights' in locals() and len(weights) < len(features_all):
        new_w[:len(weights)] = weights   
    weights = new_w

bias = 0.0  

# 5. Retrain
retrain_epochs = CONFIG["epochs"]
stable_learning_rate = CONFIG["learning_rate"]
batch_size = min(CONFIG["batch_size"], len(X_final))

for epoch in range(retrain_epochs):
    perm = np.random.permutation(len(X_final))
    X_sh = X_final[perm]
    y_sh = y_scaled[perm]  
    for i in range(0, len(X_sh), batch_size):
        X_batch = X_sh[i:i+batch_size]
        y_batch = y_sh[i:i+batch_size]

        y_pred = predict(X_batch, weights, bias)
        error  = y_pred - y_batch

        dw = (2.0 / len(y_batch)) * np.dot(X_batch.T, error)
        db = (2.0 / len(y_batch)) * np.sum(error)

        # Gradient clipping
        dw = np.clip(dw, -1.0, 1.0)
        db = np.clip(db, -1.0, 1.0)

        weights -= stable_learning_rate * dw
        bias    -= stable_learning_rate * db

    if epoch % 50 == 0:
        
        current_loss = mse_loss(y_scaled, predict(X_final, weights, bias))
        print(f"Retrain Epoch {epoch:04d} | Loss: {current_loss:.6f}")

# Save normalization stats for use in Cell 86

print(f"\nRetrain complete.")
print(f"y_mean_final = {y_mean_final:.4f}")
print(f"y_std_final  = {y_std_final:.4f}")
print(f"Weights: {weights}")
print(f"Bias:    {bias:.6f}")
# Out:
# Retrain Epoch 0000 | Loss: 0.244510
# Retrain Epoch 0050 | Loss: 0.201866
# Retrain Epoch 0100 | Loss: 0.201866
# Retrain Epoch 0150 | Loss: 0.201867
# Retrain Epoch 0200 | Loss: 0.201866
# Retrain Epoch 0250 | Loss: 0.201866
#
# Retrain complete.
# y_mean_final = 78.9607
# y_std_final  = 10.4543
# Weights: [-0.11975179 -0.10245574 -0.11276443 -0.12750707  0.64855361  0.5381877 ]
# Bias:    0.000325

# %%
#select test rows where hidden is unknown (we evaluate only those)
test_unknown = test_df[test_df[hidden_var].isna()].copy()
print("Test rows (hidden unknown):", len(test_unknown))
# Out:
# Test rows (hidden unknown): 2000

# %%
# select only known features (exclude hidden + target)

sim_features = [f for f in features_all if f != hidden_var]

print("Similarity features:", sim_features)
# Out:
# Similarity features: ['m1', 'm2', 'm3', 'm4', 'laser']

# %%
#normalise_data
labeled_train_sim = train_df[train_df[hidden_var].notna()]
X_train_sim = labeled_train_sim[sim_features].values

sim_mean = X_train_sim.mean(axis=0)
sim_std = X_train_sim.std(axis=0)

sim_std[sim_std == 0] = 1.0  

X_norm = (X_train_sim - sim_mean) / sim_std

# %%
# map weights to similarity features

feature_index = {f: i for i, f in enumerate(features_all)}

weights_sim = np.array([weights[feature_index[f]] for f in sim_features])

# normalize weights (importance)

w = np.abs(weights_sim)

if w.sum() == 0:
    w = np.ones_like(w) / len(w)
else:
    w = w / w.sum()

print("Normalized weights:", w)
# Out:
# Normalized weights: [0.10778423 0.09221668 0.10149516 0.11476447 0.58373947]

# %%
#SIMILARITY LOSS (WEIGHTED)
def similarity_loss(train_row, test_row, w):
    """ Compute weighted similarity (distance) between two vectors. """
    diff = np.abs(train_row - test_row)
    score = np.sum(w * diff)
    return score

# %%
def compute_similarity_scores(test_x):
    """
    Compute similarity scores between one test sample and all training samples (vectorized)."""

    # normalize test point
    test_norm = (test_x - sim_mean) / sim_std

    # vectorized difference (broadcasting)
    diff = np.abs(X_norm - test_norm)   

    # weighted sum across features
    scores = np.dot(diff, w)

    return scores

# %%
def get_hidden_range(nearest_rows):
    """
    Get min and max of hidden variable from nearest rows.
    """
    values = nearest_rows[hidden_var].values
    return np.min(values), np.max(values)


def get_nearest_rows(scores, k=None):
    """
    Select k nearest rows based on similarity scores.
    """
    if k is None:
        k = CONFIG["k_neighbors"]   

    labeled_train = train_df[train_df[hidden_var].notna()].reset_index(drop=True)
    
    nearest_idx = np.argsort(scores)[:k]
    
    return labeled_train.iloc[nearest_idx]

# %%
results = []

# use SAME feature space as model
feature_index = {f: i for i, f in enumerate(features)}

if hidden_var not in feature_index:
    raise ValueError(f"{hidden_var} not found in features. Fix feature selection.")

hidden_idx = feature_index[hidden_var]

buffer_pct  = CONFIG["buffer_pct"]
k_neighbors = CONFIG["k_neighbors"]


def eval_at_m5(test_x, m5_val):
    """
    Evaluate model output at a given hidden variable value.
    """
    x = np.zeros(len(features))

    std_safe = np.where(X_std_final == 0, 1.0, X_std_final)

    # fill known features (from similarity space)
    for i, f in enumerate(sim_features):
        fi = feature_index[f]
        x[fi] = (test_x[i] - X_mean_final[fi]) / std_safe[fi]

    # fill hidden variable
    x[hidden_idx] = (m5_val - X_mean_final[hidden_idx]) / std_safe[hidden_idx]

    pred = predict(x.reshape(1, -1), weights, bias)[0]

    return pred * y_std_final + y_mean_final


# MAIN LOOP
for idx, row in test_unknown.iterrows():

    test_x = row[sim_features].values.astype(float)

    # ---- Step 1: find m5 range via similarity ----
    scores = compute_similarity_scores(test_x)
    nearest_rows = get_nearest_rows(scores, k=k_neighbors)

    
    h_vals = nearest_rows[hidden_var].values
    h_low  = np.percentile(h_vals, 10)
    h_high = np.percentile(h_vals, 90)

    # ---- Step 2: propagate to target ----
    t1 = eval_at_m5(test_x, h_low)
    t2 = eval_at_m5(test_x, h_high)

    base_low  = min(t1, t2)
    base_high = max(t1, t2)

    # symmetric buffer
    width = base_high - base_low
    buffer = buffer_pct * width

    target_low  = base_low  * (1 - buffer_pct)
    target_high = base_high * (1 + buffer_pct)

  
    result = row.to_dict()
    result["hidden_low"]  = round(float(h_low),  4)
    result["hidden_high"] = round(float(h_high), 4)
    result["target_low"]  = round(float(target_low),  4)
    result["target_high"] = round(float(target_high), 4)

    results.append(result)


print(f"Predictions complete: {len(results)} rows")

if len(results) > 0:
    print(
        f"Sample: hidden=[{results[0]['hidden_low']},{results[0]['hidden_high']}]  "
        f"target=[{results[0]['target_low']:.2f},{results[0]['target_high']:.2f}]"
    )
# Out:
# Predictions complete: 2000 rows
# Sample: hidden=[2.3872,2.6412]  target=[87.17,107.84]

# %%
results_df = pd.DataFrame(results)

results_df.to_csv(CONFIG["output_path"], index=False)

print(f"CSV saved at: {CONFIG['output_path']}")
# Out:
# CSV saved at: D:\project MODEL.T\dataset\model_T_results6.csv

# %%
# check condition
results_df["in_range"] = (
    (results_df["target"] >= results_df["target_low"]) &
    (results_df["target"] <= results_df["target_high"])
)

# total rows
total = len(results_df)

# rows inside range
inside = results_df["in_range"].sum()

# percentage
percentage = (inside / total) * 100

print("Total rows:", total)
print("Rows inside range:", inside)
print("Percentage:", percentage, "%")
# Out:
# Total rows: 2000
# Rows inside range: 1815
# Percentage: 90.75 %

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score


def predict(X, weights, bias):
    return np.dot(X, weights) + bias

def mse_loss(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def train_linear(X_raw, y_raw, epochs=300, lr=0.001, batch_size=32, seed=42):
    """
    Trains a normalized linear model using SGD.
    Returns: weights, bias, X_mean, X_std, y_mean, y_std
    """
    np.random.seed(seed)

    # Normalize X
    X_mean = X_raw.mean(axis=0)
    X_std  = X_raw.std(axis=0)
    X_std[X_std == 0] = 1.0
    X = (X_raw - X_mean) / X_std

    # Normalize y
    y_mean = y_raw.mean()
    y_std  = y_raw.std()
    if y_std == 0:
        y_std = 1.0
    y = (y_raw - y_mean) / y_std

    n_features = X.shape[1]
    weights = np.random.randn(n_features) * 0.01
    bias    = 0.0
    batch_size = min(batch_size, len(X))

    for epoch in range(epochs):
        perm = np.random.permutation(len(X))
        X_sh = X[perm]
        y_sh = y[perm]
        for i in range(0, len(X_sh), batch_size):
            Xb = X_sh[i:i+batch_size]
            yb = y_sh[i:i+batch_size]
            err = predict(Xb, weights, bias) - yb
            dw = (2.0 / len(yb)) * np.dot(Xb.T, err)
            db = (2.0 / len(yb)) * np.sum(err)
            dw = np.clip(dw, -1.0, 1.0)
            db = np.clip(db, -1.0, 1.0)
            weights -= lr * dw
            bias    -= lr * db

    return weights, bias, X_mean, X_std, y_mean, y_std


def eval_on_test(test_df, features, target, weights, bias,
                 X_mean, X_std, y_mean, y_std, h_fill_value):
    """
    Evaluates R² on test set.
    h_fill_value: the value to use for hidden_var at test time (scalar or array).
    """
    X_test = test_df[features].copy()
    X_test[hidden_var] = h_fill_value   
    X_raw  = X_test.values.astype(float)
    X_std_safe = np.where(X_std == 0, 1.0, X_std)
    X_norm = (X_raw - X_mean) / X_std_safe
    y_pred_norm = predict(X_norm, weights, bias)
    y_pred = y_pred_norm * y_std + y_mean
    y_true = test_df[target].values.astype(float)
    return r2_score(y_true, y_pred), y_pred


# ── Baseline 0: No hidden variable (replicates README baseline) ──
features_no_h = [f for f in features if f != hidden_var]
X_raw_noh = train_df[features_no_h].values.astype(float)
y_raw_noh  = train_df[target].values.astype(float)
w0, b0, Xm0, Xs0, ym0, ys0 = train_linear(
    X_raw_noh, y_raw_noh,
    epochs=CONFIG['epochs'], lr=CONFIG['learning_rate'],
    batch_size=CONFIG['batch_size'], seed=CONFIG['random_seed']
)
X_test_noh = test_df[features_no_h].values.astype(float)
Xs0_safe   = np.where(Xs0 == 0, 1.0, Xs0)
y_pred_noh = (predict((X_test_noh - Xm0) / Xs0_safe, w0, b0)) * ys0 + ym0
r2_no_h    = r2_score(test_df[target].values, y_pred_noh)
print(f"Baseline (no hidden var) R²: {r2_no_h:.4f}")
print()
# Out:
# Baseline (no hidden var) R²: 0.4897

# %%
# ── BASELINE 1: MEAN IMPUTATION 


print("  BASELINE 1 — Mean Imputation")


# Step 1 — compute mean from labeled rows only
labeled_mask = train_df[hidden_var].notna()
h_mean = train_df.loc[labeled_mask, hidden_var].mean()
print(f"  Mean of known m5 values : {h_mean:.4f}")
print(f"  (from {labeled_mask.sum()} rule-labeled rows only)")

# Step 2 — fill ALL unlabeled train rows with mean
train_mean = train_df.copy()
train_mean[hidden_var] = train_mean[hidden_var].fillna(h_mean)
assert train_mean[hidden_var].isna().sum() == 0, "Still has NaN after fill"

# Step 3 — train on full training set with imputed h
X_raw_mean = train_mean[features].values.astype(float)
y_raw_mean = train_mean[target].values.astype(float)

w1, b1, Xm1, Xs1, ym1, ys1 = train_linear(
    X_raw_mean, y_raw_mean,
    epochs=CONFIG['epochs'],
    lr=CONFIG['learning_rate'],
    batch_size=CONFIG['batch_size'],
    seed=CONFIG['random_seed']
)

# Step 4 — predict on test set (fill test m5 with same mean)
r2_mean, y_pred_mean = eval_on_test(
    test_df, features, target,
    w1, b1, Xm1, Xs1, ym1, ys1,
    h_fill_value=h_mean
)

print(f"\n  Test R² (Mean Imputation) : {r2_mean:.4f}")
print(f"  Compare → No-h baseline  : {r2_no_h:.4f}")
# Out:
#   BASELINE 1 — Mean Imputation
#   Mean of known m5 values : 1.4490
#   (from 8000 rule-labeled rows only)
#
#   Test R² (Mean Imputation) : 0.4892
#   Compare → No-h baseline  : 0.4897

# %%
# ── BASELINE 2: KNN IMPUTATION

print("  BASELINE 2 — KNN Imputation")


k = CONFIG['k_neighbors']   # 10 neighbors — same as Model-T similarity search

# Observed features only (no hidden_var, no target)
obs_features = [f for f in features if f != hidden_var]

# Labeled pool — these have known m5 values
# FIX: Use clean snapshot (train_df has h already recovered by Model-T)
labeled_pool   = train_df_clean[train_df_clean[hidden_var].notna()].copy()
unlabeled_pool = train_df_clean[train_df_clean[hidden_var].isna()].copy()

X_labeled_obs = labeled_pool[obs_features].values.astype(float)
h_labeled     = labeled_pool[hidden_var].values.astype(float)

# Normalize using labeled pool statistics
obs_mean = X_labeled_obs.mean(axis=0)
obs_std  = X_labeled_obs.std(axis=0)
obs_std[obs_std == 0] = 1.0
X_labeled_norm = (X_labeled_obs - obs_mean) / obs_std

def knn_impute_h(X_query_raw, X_labeled_norm, h_labeled, obs_mean, obs_std, k):
    """
    For each row in X_query_raw, find k nearest labeled neighbors
    and return mean of their h values.
    """
    X_query_norm = (X_query_raw - obs_mean) / obs_std
    h_imputed = np.zeros(len(X_query_norm))

    for i, q in enumerate(X_query_norm):
        # Euclidean distance to all labeled rows
        dists = np.sqrt(np.sum((X_labeled_norm - q) ** 2, axis=1))
        nearest_idx = np.argsort(dists)[:k]
        h_imputed[i] = h_labeled[nearest_idx].mean()

    return h_imputed

# Impute unlabeled train rows
X_unlabeled_obs = unlabeled_pool[obs_features].values.astype(float)
print(f"  Imputing {len(X_unlabeled_obs)} unlabeled train rows (k={k})...")
h_knn_unlabeled = knn_impute_h(
    X_unlabeled_obs, X_labeled_norm, h_labeled, obs_mean, obs_std, k
)

# Clip to valid range from rules
h_low_clip, h_high_clip = rules['variables'][hidden_var]['range']
h_knn_unlabeled = np.clip(h_knn_unlabeled, h_low_clip, h_high_clip)

# Build full training set with imputed h
train_knn = train_df_clean.copy()  # FIX: start from clean copy
train_knn.loc[unlabeled_pool.index, hidden_var] = h_knn_unlabeled
assert train_knn[hidden_var].isna().sum() == 0
print(f"  Recovered h range: [{h_knn_unlabeled.min():.3f}, {h_knn_unlabeled.max():.3f}]")

# Train
X_raw_knn = train_knn[features].values.astype(float)
y_raw_knn  = train_knn[target].values.astype(float)
w2, b2, Xm2, Xs2, ym2, ys2 = train_linear(
    X_raw_knn, y_raw_knn,
    epochs=CONFIG['epochs'],
    lr=CONFIG['learning_rate'],
    batch_size=CONFIG['batch_size'],
    seed=CONFIG['random_seed']
)

# Impute test rows too — use KNN from labeled pool
X_test_obs = test_df[obs_features].values.astype(float)
print(f"  Imputing {len(X_test_obs)} test rows...")
h_knn_test = knn_impute_h(
    X_test_obs, X_labeled_norm, h_labeled, obs_mean, obs_std, k
)
h_knn_test = np.clip(h_knn_test, h_low_clip, h_high_clip)

r2_knn, y_pred_knn = eval_on_test(
    test_df, features, target,
    w2, b2, Xm2, Xs2, ym2, ys2,
    h_fill_value=h_knn_test
)

print(f"\n  Test R² (KNN Imputation) : {r2_knn:.4f}")
print(f"  Compare → No-h baseline : {r2_no_h:.4f}")
print(f"  Compare → Mean baseline : {r2_mean:.4f}")
# Out:
#   BASELINE 2 — KNN Imputation
#   Imputing 5606 unlabeled train rows (k=10)...
#   Recovered h range: [0.052, 2.907]
#   Imputing 2000 test rows...
#
#   Test R² (KNN Imputation) : 0.4941
#   Compare → No-h baseline : 0.4897
#   Compare → Mean baseline : 0.4892

# %%
# ── BASELINE 3: MICE
from sklearn.experimental import enable_iterative_imputer   # noqa
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge

print("  BASELINE 3 — MICE Imputation")



mice_cols = features   
# Fit MICE on training data
mice_imputer = IterativeImputer(
    estimator=BayesianRidge(),   
    max_iter=10,
    random_state=CONFIG['random_seed'],
    verbose=0
)

# Train matrix: only feature columns (no target)

train_mice_matrix = train_df_clean[mice_cols].copy().values.astype(float)

print("  Fitting MICE on training data...")
mice_imputer.fit(train_mice_matrix)

# Transform training data
train_mice_filled = mice_imputer.transform(train_mice_matrix)
train_mice_df = pd.DataFrame(train_mice_filled, columns=mice_cols)

# Clip imputed h to valid range
h_low_clip, h_high_clip = rules['variables'][hidden_var]['range']
train_mice_df[hidden_var] = train_mice_df[hidden_var].clip(h_low_clip, h_high_clip)

h_mice_recovered = train_mice_df[hidden_var].values[
    train_df_clean[hidden_var].isna().values  # FIX: use clean mask
]
print(f"  Recovered h range (unlabeled): [{h_mice_recovered.min():.3f}, {h_mice_recovered.max():.3f}]")

# Train model
X_raw_mice = train_mice_df[features].values.astype(float)
y_raw_mice  = train_df_clean[target].values.astype(float)  
w3, b3, Xm3, Xs3, ym3, ys3 = train_linear(
    X_raw_mice, y_raw_mice,
    epochs=CONFIG['epochs'],
    lr=CONFIG['learning_rate'],
    batch_size=CONFIG['batch_size'],
    seed=CONFIG['random_seed']
)

# Impute test rows — stack with train so MICE has context

test_mice_matrix = test_df[mice_cols].copy().values.astype(float)

# MICE transform on test rows directly (fitted on train)
print("  Imputing test rows with MICE...")
test_mice_filled = mice_imputer.transform(test_mice_matrix)
test_mice_df = pd.DataFrame(test_mice_filled, columns=mice_cols)
test_mice_df[hidden_var] = test_mice_df[hidden_var].clip(h_low_clip, h_high_clip)
h_mice_test = test_mice_df[hidden_var].values

r2_mice, y_pred_mice = eval_on_test(
    test_df, features, target,
    w3, b3, Xm3, Xs3, ym3, ys3,
    h_fill_value=h_mice_test
)

print(f"\n  Test R² (MICE)           : {r2_mice:.4f}")
print(f"  Compare → No-h baseline : {r2_no_h:.4f}")
print(f"  Compare → Mean baseline : {r2_mean:.4f}")
print(f"  Compare → KNN baseline  : {r2_knn:.4f}")
# Out:
#   BASELINE 3 — MICE Imputation
#   Fitting MICE on training data...
#   Recovered h range (unlabeled): [0.678, 2.292]
#   Imputing test rows with MICE...
#
#   Test R² (MICE)           : 0.4897
#   Compare → No-h baseline : 0.4897
#   Compare → Mean baseline : 0.4892
#   Compare → KNN baseline  : 0.4941

# %%
# ── BASELINE 4: EM ALGORITHM 
from scipy.stats import mode as scipy_mode
from sklearn.neighbors import NearestNeighbors


print("  BASELINE 4 — EM Algorithm")


# Safety: rebuild clean snapshot if needed
if 'train_df_clean' not in dir() or train_df_clean[hidden_var].isna().sum() == 0:
    _raw = train_df.copy()
    _raw[hidden_var] = np.nan
    for rule in rules.get('rules', []):
        _mask = _raw.eval(rule['condition'])
        for _var, _val in rule['assign'].items():
            _raw.loc[_mask & _raw[_var].isna(), _var] = _val
    train_df_clean = _raw
    print('  [Info] Rebuilt train_df_clean from rules')

# Discrete h values from RULE-LABELED rows only (not recovered values)
h_low_clip, h_high_clip = rules['variables'][hidden_var]['range']
h_values = np.array([float(v) for v in
    sorted(train_df_clean[train_df_clean[hidden_var].notna()][hidden_var].unique())
])
print(f"  Discrete h values found : {h_values}")
print(f"  (should be 4 clean values: 0, 1, 2, 3)")

labeled_mask_em   = train_df_clean[hidden_var].notna()
unlabeled_mask_em = train_df_clean[hidden_var].isna()
n_unlabeled       = unlabeled_mask_em.sum()
print(f"  Unlabeled rows to fill  : {n_unlabeled}")

# ── Initialize: fill unlabeled with mean h (warm start) ──
train_em = train_df_clean.copy()
h_init   = train_df_clean.loc[labeled_mask_em, hidden_var].mean()
train_em.loc[unlabeled_mask_em, hidden_var] = h_init

max_em_iter = 20
em_lr        = CONFIG['learning_rate']
em_epochs    = 150
em_batch     = CONFIG['batch_size']

prev_h_assignments = None

for em_iter in range(max_em_iter):

    # ── M-STEP: train model on all rows with current h ──
    X_em_raw = train_em[features].values.astype(float)
    y_em_raw = train_em[target].values.astype(float)

    w_em, b_em, Xm_em, Xs_em, ym_em, ys_em = train_linear(
        X_em_raw, y_em_raw,
        epochs=em_epochs, lr=em_lr,
        batch_size=em_batch, seed=CONFIG['random_seed']
    )

    # ── E-STEP (TRAINING): pick h that minimises residual for unlabeled rows ──
    
unlabeled_rows_em = train_em[unlabeled_mask_em].copy()
Xs_em_safe = np.where(Xs_em == 0, 1.0, Xs_em)

X_unlab = unlabeled_rows_em[features].values.astype(float)  
y_unlab = unlabeled_rows_em[target].values.astype(float)     
hidden_idx = features.index(hidden_var)

best_h    = np.full(n_unlabeled, h_values[0])
best_loss = np.full(n_unlabeled, np.inf)

for h_val in h_values:   
    X_try = X_unlab.copy()
    X_try[:, hidden_idx] = h_val

    X_norm = (X_try - Xm_em) / Xs_em_safe         
    y_hat  = (X_norm @ w_em + b_em) * ys_em + ym_em  
    loss   = (y_unlab - y_hat) ** 2                 

    improved = loss < best_loss
    best_loss = np.where(improved, loss, best_loss)
    best_h    = np.where(improved, h_val, best_h)

train_em.loc[unlabeled_mask_em, hidden_var] = best_h
new_h = best_h

# ── Test-time prediction — 

print("\n  Predicting test set (KNN mode on converged h — no leakage)...")

obs_feats = [f for f in features if f != hidden_var]
obs_idx   = [i for i, f in enumerate(features) if f != hidden_var]
Xm_obs    = Xm_em[obs_idx]
Xs_obs    = np.where(Xs_em[obs_idx] == 0, 1.0, Xs_em[obs_idx])

X_train_obs  = train_em[obs_feats].values.astype(float)
X_train_norm = (X_train_obs - Xm_obs) / Xs_obs
h_train_conv = train_em[hidden_var].values

nn_em = NearestNeighbors(n_neighbors=CONFIG['k_neighbors'])
nn_em.fit(X_train_norm)

X_test_obs       = test_df[obs_feats].values.astype(float)
X_test_norm      = (X_test_obs - Xm_obs) / Xs_obs
_, neighbor_idxs = nn_em.kneighbors(X_test_norm)

h_em_test = np.array([
    scipy_mode(h_train_conv[neighbor_idxs[i]], keepdims=False).mode
    for i in range(len(test_df))
])
h_em_test = np.clip(h_em_test, h_low_clip, h_high_clip)

print(f"  h assigned at test time — unique values: {np.unique(h_em_test)}")

r2_em, y_pred_em = eval_on_test(
    test_df, features, target,
    w_em, b_em, Xm_em, Xs_em, ym_em, ys_em,
    h_fill_value=h_em_test
)

print(f"\n  Test R² (EM — no leakage) : {r2_em:.4f}")
print(f"  Compare → No-h baseline   : {r2_no_h:.4f}")
print(f"  Compare → Mean baseline   : {r2_mean:.4f}")
print(f"  Compare → KNN baseline    : {r2_knn:.4f}")
print(f"  Compare → MICE            : {r2_mice:.4f}")
# Out:
#   BASELINE 4 — EM Algorithm
#   Discrete h values found : [1.58841750e-04 1.65347700e-03 1.87708125e-03 ... 2.99503984e+00
#  2.99802907e+00 2.99866894e+00]
#   (should be 4 clean values: 0, 1, 2, 3)
#   Unlabeled rows to fill  : 5606
#
#   Predicting test set (KNN mode on converged h — no leakage)...
#   h assigned at test time — unique values: [1.58841750e-04 1.65347700e-03 4.60612575e-03 5.16552000e-03
#  5.32028250e-03 8.97573750e-03 9.75023250e-03 1.03719525e-02
#  1.10288265e-02 1.84377150e-02 2.14560900e-02 2.72911065e-02
#  2.76856890e-02 3.04909650e-02 3.46698173e-02 3.49751340e-02
#  3.94860075e-02 4.24639500e-02 4.86198225e-02 5.36112825e-02
#  6.10371732e-02 6.56430105e-02 6.80193900e-02 8.27024580e-02
#  9.04105785e-02 9.04254030e-02 9.67416443e-02 9.84225510e-02
#  9.89874247e-02 1.00223190e-01 1.03802302e-01 1.14691920e-01
#  1.27590722e-01 1.30351935e-01 1.32016590e-01 1.38575332e-01
#  1.42002045e-01 1.48919000e-01 1.61451599e-01 1.81958638e-01
#  2.00542298e-01 2.03232188e-01 2.05077326e-01 2.06078408e-01
#  2.07714532e-01 2.13717734e-01 2.18077693e-01 2.18243297e-01
#  2.19282796e-01 2.19699487e-01 2.27354491e-01 2.34623500e-01
#  2.43790672e-01 2.45694067e-01 2.65397417e-01 2.69820363e-01
#  2.70592741e-01 2.89275607e-01 2.98340752e-01 3.00520600e-01
#  3.10785803e-01 3.14727763e-01 3.16819876e-01 3.20416108e-01
#  3.22627755e-01 3.25714099e-01 3.33934538e-01 3.40986135e-01
#  3.41371703e-01 3.42114910e-01 3.44736520e-01 3.46722600e-01
#  3.47195180e-01 3.47254732e-01 3.55659937e-01 3.56584374e-01
#  3.61561860e-01 3.62436840e-01 3.65891468e-01 3.68084523e-01
#  3.81529391e-01 3.83314270e-01 3.83703709e-01 3.87732694e-01
#  3.91859571e-01 3.92079908e-01 3.92374877e-01 3.99475304e-01
#  4.17047753e-01 4.22685572e-01 4.28805880e-01 4.33450894e-01
#  4.37287568e-01 4.38135431e-01 4.40255528e-01 4.52119765e-01
#  4.59758861e-01 4.65392638e-01 4.67819340e-01 4.69797014e-01
#  4.71626700e-01 4.81324763e-01 4.95643853e-01 4.97862068e-01
#  4.99462672e-01 5.00368680e-01 5.15272798e-01 5.24051654e-01
#  5.24570638e-01 5.28666736e-01 5.40324877e-01 5.41512528e-01
#  5.51203149e-01 5.59284705e-01 5.73011925e-01 5.81496251e-01
#  5.89230583e-01 5.98446540e-01 5.99447243e-01 6.24945591e-01
#  6.32568721e-01 6.37245286e-01 6.43438643e-01 6.44118180e-01
#  6.47643311e-01 6.49537177e-01 6.59452221e-01 6.61992761e-01
#  6.73842746e-01 6.78181831e-01 6.84988665e-01 6.93424845e-01
#  7.00150335e-01 7.05525367e-01 7.05721373e-01 7.11313313e-01
#  7.25738797e-01 7.26348396e-01 7.39287480e-01 7.44873367e-01
#  7.46725478e-01 7.46950057e-01 7.52612581e-01 7.54926657e-01
#  7.62597895e-01 7.66184633e-01 7.71241178e-01 7.74746885e-01
#  7.91618739e-01 7.94136611e-01 8.00974012e-01 8.14423718e-01
#  8.20096080e-01 8.20248120e-01 8.32459997e-01 8.39934308e-01
#  8.41340197e-01 8.46430420e-01 8.58358830e-01 8.58456086e-01
#  8.83418911e-01 8.83646103e-01 8.84262705e-01 8.90362177e-01
#  8.96314279e-01 8.98633829e-01 9.18037082e-01 9.27323484e-01
#  9.30313057e-01 9.34732868e-01 9.58347533e-01 9.68101567e-01
#  9.85046338e-01 9.89607395e-01 9.95461783e-01 9.99911450e-01
#  1.00548507e+00 1.00759255e+00 1.00810582e+00 1.02364040e+00
#  1.02843788e+00 1.03099195e+00 1.03355306e+00 1.03384832e+00
#  1.04476684e+00 1.04765730e+00 1.05431421e+00 1.05620214e+00
#  1.06382417e+00 1.06406310e+00 1.06437051e+00 1.06572504e+00
#  1.06701478e+00 1.06884103e+00 1.07291682e+00 1.07759196e+00
#  1.07972906e+00 1.08926955e+00 1.09378271e+00 1.10262415e+00
#  1.10738212e+00 1.11029985e+00 1.11545373e+00 1.12378481e+00
#  1.12448376e+00 1.13678672e+00 1.15220489e+00 1.15517939e+00
#  1.16211965e+00 1.16567964e+00 1.16571049e+00 1.16890699e+00
#  1.16925104e+00 1.17248045e+00 1.17728772e+00 1.18731626e+00
#  1.18912478e+00 1.18996528e+00 1.19168520e+00 1.19462146e+00
#  1.19908966e+00 1.19920114e+00 1.20490734e+00 1.20877026e+00
#  1.20935893e+00 1.21248085e+00 1.21490459e+00 1.21593968e+00
#  1.21739116e+00 1.22453690e+00 1.22776438e+00 1.24794009e+00
#  1.24854234e+00 1.26894075e+00 1.27081910e+00 1.27777390e+00
#  1.27816120e+00 1.28563867e+00 1.28682500e+00 1.28736436e+00
#  1.29409737e+00 1.30244142e+00 1.30320427e+00 1.31359226e+00
#  1.31421231e+00 1.31836161e+00 1.35202297e+00 1.35280582e+00
#  1.35389613e+00 1.35891241e+00 1.35987740e+00 1.36877720e+00
#  1.37218773e+00 1.37841131e+00 1.38767488e+00 1.39874064e+00
#  1.41044607e+00 1.41786746e+00 1.42098414e+00 1.42844966e+00
#  1.42958516e+00 1.43280685e+00 1.44244095e+00 1.44635199e+00
#  1.44661907e+00 1.44726740e+00 1.45849711e+00 1.47644803e+00
#  1.48386148e+00 1.49539378e+00 1.49652051e+00 1.50630281e+00
#  1.51319849e+00 1.52121288e+00 1.53028949e+00 1.53097353e+00
#  1.53181141e+00 1.54791109e+00 1.55186764e+00 1.55367827e+00
#  1.56479021e+00 1.58090211e+00 1.58756511e+00 1.59750415e+00
#  1.60619698e+00 1.61076646e+00 1.61582490e+00 1.61687891e+00
#  1.62038028e+00 1.62334052e+00 1.63011948e+00 1.63232173e+00
#  1.64520200e+00 1.64533266e+00 1.64675496e+00 1.65778421e+00
#  1.66005899e+00 1.66320913e+00 1.66663725e+00 1.66760773e+00
#  1.68195730e+00 1.68581453e+00 1.69822015e+00 1.70110101e+00
#  1.70742549e+00 1.70805004e+00 1.70874868e+00 1.70918421e+00
#  1.72160062e+00 1.74611530e+00 1.75540944e+00 1.76661563e+00
#  1.76922327e+00 1.77071355e+00 1.77779141e+00 1.78300380e+00
#  1.78490661e+00 1.78518464e+00 1.79075256e+00 1.79230547e+00
#  1.79244305e+00 1.79971379e+00 1.80734456e+00 1.80855160e+00
#  1.81674201e+00 1.84111420e+00 1.84939418e+00 1.84951313e+00
#  1.84991390e+00 1.85160015e+00 1.85191347e+00 1.85838749e+00
#  1.87335424e+00 1.87991740e+00 1.88621871e+00 1.89741491e+00
#  1.89943344e+00 1.90323085e+00 1.90654241e+00 1.91931274e+00
#  1.92945387e+00 1.94629638e+00 1.95882046e+00 1.96349523e+00
#  1.97123393e+00 1.97977527e+00 1.98012017e+00 1.99007978e+00
#  2.00444166e+00 2.01409701e+00 2.01556183e+00 2.01581947e+00
#  2.01848362e+00 2.02312914e+00 2.02546160e+00 2.03226609e+00
#  2.03588323e+00 2.03698598e+00 2.05096239e+00 2.05213628e+00
#  2.05747519e+00 2.05975042e+00 2.06516426e+00 2.07856558e+00
#  2.07902247e+00 2.08096658e+00 2.08887882e+00 2.09086761e+00
#  2.09414998e+00 2.10084895e+00 2.10423463e+00 2.11703273e+00
#  2.12062583e+00 2.12622543e+00 2.13621398e+00 2.13805744e+00
#  2.13951425e+00 2.14216343e+00 2.15146740e+00 2.15471048e+00
#  2.15587086e+00 2.15723260e+00 2.15824666e+00 2.15828675e+00
#  2.17489437e+00 2.18092491e+00 2.18192660e+00 2.18567048e+00
#  2.19129485e+00 2.19706140e+00 2.20328167e+00 2.20664421e+00
#  2.20903482e+00 2.21007768e+00 2.21343960e+00 2.22581267e+00
#  2.23001115e+00 2.23038459e+00 2.23152864e+00 2.23523136e+00
#  2.23562215e+00 2.23571546e+00 2.25209512e+00 2.25232846e+00
#  2.26075076e+00 2.26264058e+00 2.26608159e+00 2.26838107e+00
#  2.27708183e+00 2.28413179e+00 2.28554732e+00 2.29968744e+00
#  2.30975115e+00 2.31305143e+00 2.32488935e+00 2.32690184e+00
#  2.32804634e+00 2.33321589e+00 2.34304396e+00 2.35288133e+00
#  2.36309158e+00 2.36679954e+00 2.37072362e+00 2.37525844e+00
#  2.37982755e+00 2.38321671e+00 2.38595761e+00 2.38645355e+00
#  2.38717735e+00 2.38856857e+00 2.40877756e+00 2.41311078e+00
#  2.42748101e+00 2.42768107e+00 2.43400534e+00 2.43521834e+00
#  2.44403816e+00 2.44790689e+00 2.45121292e+00 2.45810065e+00
#  2.46130175e+00 2.47296899e+00 2.48074465e+00 2.48320377e+00
#  2.48474169e+00 2.48600552e+00 2.50674491e+00 2.51315182e+00
#  2.52026607e+00 2.52225349e+00 2.54281720e+00 2.54864170e+00
#  2.56705064e+00 2.57808382e+00 2.58274913e+00 2.58407072e+00
#  2.59178138e+00 2.59606219e+00 2.59775190e+00 2.60678859e+00
#  2.61297989e+00 2.61540579e+00 2.61721438e+00 2.61841775e+00
#  2.62060302e+00 2.62570750e+00 2.62986868e+00 2.62991494e+00
#  2.62993472e+00 2.64386159e+00 2.64551193e+00 2.65529785e+00
#  2.65606487e+00 2.67715243e+00 2.69027233e+00 2.69744259e+00
#  2.69835484e+00 2.69869567e+00 2.70281645e+00 2.70350735e+00
#  2.71114087e+00 2.71396222e+00 2.73652628e+00 2.73698512e+00
#  2.74356215e+00 2.76649646e+00 2.77040665e+00 2.78136267e+00
#  2.78894305e+00 2.80870423e+00 2.84046964e+00 2.99866894e+00]
#
#   Test R² (EM — no leakage) : 0.4285
#   Compare → No-h baseline   : 0.4897
#   Compare → Mean baseline   : 0.4892
#   Compare → KNN baseline    : 0.4941
#   Compare → MICE            : 0.4897

# %%
# ── FINAL COMPARISON TABLE ────────────────────────────────────────────────────

# Replace the Model-T R² below with your actual value from the pipeline.


results_df_loaded = pd.read_csv(CONFIG['output_path'])
y_true_test  = results_df_loaded['target'].values
y_mid_model_t = (results_df_loaded['target_low'].values +
                 results_df_loaded['target_high'].values) / 2
r2_model_t   = r2_score(y_true_test, y_mid_model_t)

print("  FINAL COMPARISON TABLE")
print(f"  {'Method':<28} {'R²':>8}")
print("  " + "-" * 38)
print(f"  {'No hidden var (baseline)':<28} {r2_no_h:>8.4f}")
print(f"  {'Mean imputation':<28} {r2_mean:>8.4f}")
print(f"  {'KNN imputation (k=10)':<28} {r2_knn:>8.4f}")
print(f"  {'MICE':<28} {r2_mice:>8.4f}")
print(f"  {'EM algorithm':<28} {r2_em:>8.4f}")
print(f"  {'Model-T (interval midpoint)':<28} {r2_model_t:>8.4f}")
print("  " + "-" * 38)
print(f"  {'Oracle (true h known)':<28} {'~0.50':>8}  [README target]")

print()
print("  Coverage (Model-T only):")
in_range = (
    (results_df_loaded['target'] >= results_df_loaded['target_low']) &
    (results_df_loaded['target'] <= results_df_loaded['target_high'])
)
print(f"  {in_range.sum()} / {len(in_range)} rows inside interval  "
      f"({in_range.mean()*100:.1f}%)")
# Out:
#   FINAL COMPARISON TABLE
#   Method                             R²
#   --------------------------------------
#   No hidden var (baseline)       0.4897
#   Mean imputation                0.4892
#   KNN imputation (k=10)          0.4941
#   MICE                           0.4897
#   EM algorithm                   0.4285
#   Model-T (interval midpoint)    0.4934
#   --------------------------------------
#   Oracle (true h known)           ~0.50  [README target]
#
#   Coverage (Model-T only):
#   1815 / 2000 rows inside interval  (90.8%)

# %%
results_df["interval_length"] = results_df["target_high"] - results_df["target_low"]

print(f"Average interval length : {results_df['interval_length'].mean():.4f}")
print(f"Median interval length  : {results_df['interval_length'].median():.4f}")
print(f"Min interval length     : {results_df['interval_length'].min():.4f}")
print(f"Max interval length     : {results_df['interval_length'].max():.4f}")
# Out:
# Average interval length : 25.3214
# Median interval length  : 28.0544
# Min interval length     : 13.1126
# Max interval length     : 32.5474

# %%
results_df["hidden_length"] = results_df["hidden_high"] - results_df["hidden_low"]

print(f"Average m5 interval length : {results_df['hidden_length'].mean():.4f}")
print(f"Median m5 interval length  : {results_df['hidden_length'].median():.4f}")
print(f"Min m5 interval length     : {results_df['hidden_length'].min():.4f}")
print(f"Max m5 interval length     : {results_df['hidden_length'].max():.4f}")
# Out:
# Average m5 interval length : 2.0517
# Median m5 interval length  : 3.0000
# Min m5 interval length     : 0.0556
# Max m5 interval length     : 3.0000
